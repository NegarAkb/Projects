# %%
# %matplotlib inline
# !pip install gurobipy

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
import gurobipy as gp
from gurobipy import GRB
from time import time
# Out:
# Requirement already satisfied: gurobipy in /Applications/anaconda3/lib/python3.8/site-packages (9.5.0)

# %% [markdown]
# ## Question 1:

# %%
def read_data():
    data = pd.read_csv('constants.csv')
    P = data['value'][0]
    R = data['value'][1]
    n = data['value'][2]
    return (P,R,n)

# %%
def instance_data(number_of_instance):
    instance = pd.read_csv('instance_'+str(number_of_instance)+'.csv')
    m = instance.shape[0]
    p = []
    r = []
    for p_i in instance['p_i']:
        p.append(p_i)
    for r_i in instance['r_i']:
        r.append(r_i)
    return (m,p,r)

# %%
def Model( number_of_instance , m , p , r , P , R , n ):
    global model, x_vars , y_vars , run_time
    model = gp.Model("q1_instance_"+str(number_of_instance))
    model.Params.Presolve = 0
    x_vars = {}
    y_vars = {}
    start = time()
    for i in range(n):
        for j in range(m):
            x_vars[i,j] = 0 
    for i in range(m):
        y_vars [i] = 0
    constructVars() 
    contructConstrs()
    constructObj() 
    model.write('test.lp')
    model.optimize()

# %%
def constructVars(): 
    global n , m , model, x_vars ,y_vars
    for i in range( m ): 
        for j in range( n ): 
            var = model.addVar( vtype = GRB.BINARY , name = "x_" + str( i+1 ) + "_" + str( j+1 ) ) 
            x_vars[ i , j ] = var 
    model.update()
    for j in range( n ):
        var_2 = model.addVar( vtype = GRB.BINARY , name = "y_" + str( j+1 )) 
        y_vars[ j ] = var_2
    model.update()

# %%
def contructConstrs(): 
    global n , m , model , x_vars , y_vars , R, P
    for i in range( m ): 
        constExpr_0 = gp.LinExpr() 
        for j in range( n ): 
            constExpr_0 += 1.0 * x_vars[ i,j ] 
        model.addConstr( lhs = constExpr_0 , sense = GRB.EQUAL , rhs = 1 ) 

    for i in range( n ):
        constExpr_1_1 = gp.LinExpr()
        constExpr_1_2 = gp.LinExpr()
        for j in range( m ):
            constExpr_1_1 = 1.0 * x_vars[i,j]
            constExpr_1_2 = 1.0 * y_vars[j]
            model.addConstr(lhs= constExpr_1_1, sense = GRB.LESS_EQUAL , rhs = constExpr_1_2)
            
    for j in range( n ):
        constExpr_2 = gp.LinExpr()
        rhs_exp = gp.LinExpr()
        for i in range( m ): 
            constExpr_2 += p[j] * x_vars[ i,j ]
            rhs_exp = P * y_vars[j] 
        model.addLConstr( name = 'memory capacity constraints'+str(j+1),lhs = constExpr_2 , sense = GRB.LESS_EQUAL , rhs = rhs_exp  ) 
    model.update()
    
    for j in range( n ):
        constExpr_3 = gp.LinExpr()
        rhs_exp_3 = gp.LinExpr()
        for i in range( m ): 
            constExpr_3 += r[j] * x_vars[ i,j ]
            rhs_exp_3 = R * y_vars[j] 
        model.addLConstr( name = 'time capacity constraints'+str(j+1),lhs = constExpr_3 , sense = GRB.LESS_EQUAL , rhs = rhs_exp_3  ) 
    model.update()

# %%
def constructObj(): 
    global m , n , model , x_vars , y_vars
    objExpr = gp.LinExpr()
    for j in range( n ):
        objExpr += y_vars[j]
    model.setObjective( objExpr , GRB.MINIMIZE ) 
    model.update()

# %%
def processing_result(): #source: Gurobi website (https://www.gurobi.com/documentation/9.5/examples/mip2_py.html)
    # Read and solve model

    if model.IsMIP == 0:
        print('Model is not a MIP')
        sys.exit(0)

    model.optimize()

    if model.Status == GRB.OPTIMAL:
        print('Optimal objective: %g' % model.ObjVal)
    elif model.Status == GRB.INF_OR_UNBD:
        print('Model is infeasible or unbounded')
        sys.exit(0)
    elif model.Status == GRB.INFEASIBLE:
        print('Model is infeasible')
        sys.exit(0)
    elif model.Status == GRB.UNBOUNDED:
        print('Model is unbounded')
        sys.exit(0)
    else:
        print('Optimization ended with status %d' % model.Status)
        sys.exit(0)

    # Iterate over the solutions and compute the objectives
    model.Params.OutputFlag = 0
    print('')
    for k in range(model.SolCount):
        model.Params.SolutionNumber = k
        print('Solution %d has objective %g' % (k, model.PoolObjVal))
    print('')
    model.Params.OutputFlag = 1

    fixed = model.fixed()
    fixed.Params.Presolve = 0
    fixed.optimize()

    if fixed.Status != GRB.OPTIMAL:
        print("Error: fixed model isn't optimal")
        sys.exit(1)

    diff = model.ObjVal - fixed.ObjVal

    if abs(diff) > 1e-6 * (1.0 + abs(model.ObjVal)):
        print('Error: objective values are different')
        sys.exit(1)

# %%
for i in range(10):
    number_of_instance = i
    m , p , r = instance_data( number_of_instance )
    P,R,n = read_data()
    print('\n instnce '+str(number_of_instance)+'\n--------------------')
    Model( number_of_instance , m , p , r , P , R , n)
    for k in range(model.SolCount):
        model.Params.SolutionNumber = k
        print('Solution %d has objective %g' % (k, model.PoolObjVal))
    print('\n----------------------------------------------------------------\n\n')
# Out:
#  instnce 0
# --------------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-19
# Set parameter Presolve to value 0
# Warning: constraint name "memory capacity constraints1" has a space
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0xb35a50b5
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 11.0000000
# Variable types: 0 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 5.508200e+00, 325 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    5.50820    0   12   11.00000    5.50820  49.9%     -    0s
# H    0     0                       7.0000000    5.50820  21.3%     -    0s
#      0     0     cutoff    0         7.00000    7.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 7
#   MIR: 2
#   GUB cover: 4
#   RLT: 3
#
# Explored 1 nodes (420 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Solution 0 has objective 7
# Solution 1 has objective 11
#
# ----------------------------------------------------------------
#
#
#
#  instnce 1
# --------------------
# Set parameter Presolve to value 0
# Warning: constraint name "memory capacity constraints1" has a space
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0xacac22dd
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 12.0000000
# Variable types: 0 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 5.498760e+00, 314 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    5.49876    0    9   12.00000    5.49876  54.2%     -    0s
# H    0     0                       6.0000000    5.49876  8.35%     -    0s
#
# Explored 1 nodes (460 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 6 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# Solution 0 has objective 6
# Solution 1 has objective 12
#
# ----------------------------------------------------------------
#
#
#
#  instnce 2
# --------------------
# Set parameter Presolve to value 0
# Warning: constraint name "memory capacity constraints1" has a space
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0x71659c02
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 10.0000000
# Variable types: 0 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 5.155325e+00, 382 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    5.15532    0   10   10.00000    5.15532  48.4%     -    0s
# H    0     0                       7.0000000    5.15532  26.4%     -    0s
# H    0     0                       6.0000000    6.00000  0.00%     -    0s
#      0     0          -    0         6.00000    6.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 5
#   GUB cover: 1
#   RLT: 3
#
# Explored 1 nodes (476 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 6 7 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# Solution 0 has objective 6
# Solution 1 has objective 7
# Solution 2 has objective 10
#
# ----------------------------------------------------------------
#
#
#
#  instnce 3
# --------------------
# Set parameter Presolve to value 0
# Warning: constraint name "memory capacity constraints1" has a space
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0x220d7f18
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 9.0000000
# Variable types: 0 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 4.911429e+00, 283 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.91143    0   10    9.00000    4.91143  45.4%     -    0s
# H    0     0                       7.0000000    4.91143  29.8%     -    0s
# H    0     0                       6.0000000    4.91143  18.1%     -    0s
#      0     0     cutoff    0         6.00000    6.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 2
#   GUB cover: 3
#   RLT: 1
#
# Explored 1 nodes (367 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 6 7 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# Solution 0 has objective 6
# Solution 1 has objective 7
# Solution 2 has objective 9
#
# ----------------------------------------------------------------
#
#
#
#  instnce 4
# --------------------
# Set parameter Presolve to value 0
# Warning: constraint name "memory capacity constraints1" has a space
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0x4776d327
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 11.0000000
# Variable types: 0 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 6.278605e+00, 400 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    6.27860    0   11   11.00000    6.27860  42.9%     -    0s
# H    0     0                       9.0000000    6.27860  30.2%     -    0s
# H    0     0                       8.0000000    6.27860  21.5%     -    0s
#      0     0     cutoff    0         8.00000    8.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 9
#   MIR: 3
#   GUB cover: 4
#   RLT: 2
#
# Explored 1 nodes (489 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 8 9 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+00, best bound 8.000000000000e+00, gap 0.0000%
# Solution 0 has objective 8
# Solution 1 has objective 9
# Solution 2 has objective 11
#
# ----------------------------------------------------------------
#
#
#
#  instnce 5
# --------------------
# Set parameter Presolve to value 0
# Warning: constraint name "memory capacity constraints1" has a space
# <ipython-input-4-a4d1628fcced>:14: DeprecationWarning: Deprecated, pass a TempConstr or use Model.addLConstr
#   contructConstrs()
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0xda80f289
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 10.0000000
# Variable types: 0 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 4.679127e+00, 365 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.67913    0   11   10.00000    4.67913  53.2%     -    0s
# H    0     0                       7.0000000    4.67913  33.2%     -    0s
# H    0     0                       6.0000000    4.67913  22.0%     -    0s
#      0     0     cutoff    0         6.00000    6.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 2
#   GUB cover: 2
#   RLT: 4
#
# Explored 1 nodes (536 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 6 7 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# Solution 0 has objective 6
# Solution 1 has objective 7
# Solution 2 has objective 10
#
# ----------------------------------------------------------------
#
#
#
#  instnce 6
# --------------------
# Set parameter Presolve to value 0
# Warning: constraint name "memory capacity constraints1" has a space
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0x9f4dc489
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 10.0000000
# Variable types: 0 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 2.991754e+00, 339 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.99175    0   10   10.00000    2.99175  70.1%     -    0s
# H    0     0                       4.0000000    2.99175  25.2%     -    0s
#      0     0 infeasible    0         4.00000    4.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   GUB cover: 1
#   RLT: 2
#
# Explored 1 nodes (454 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 4 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# Solution 0 has objective 4
# Solution 1 has objective 10
#
# ----------------------------------------------------------------
#
#
#
#  instnce 7
# --------------------
# Set parameter Presolve to value 0
# Warning: constraint name "memory capacity constraints1" has a space
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0xdfc87825
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 10.0000000
# Variable types: 0 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 4.934549e+00, 350 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.93455    0   11   10.00000    4.93455  50.7%     -    0s
# H    0     0                       7.0000000    4.93455  29.5%     -    0s
#      0     0     cutoff    0         7.00000    7.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 11
#   MIR: 2
#   GUB cover: 4
#   RLT: 2
#
# Explored 1 nodes (464 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Solution 0 has objective 7
# Solution 1 has objective 10
#
# ----------------------------------------------------------------
#
#
#
#  instnce 8
# --------------------
# Set parameter Presolve to value 0
# Warning: constraint name "memory capacity constraints1" has a space
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0x90acc8fa
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 10.0000000
# Variable types: 0 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 4.958384e+00, 371 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.95838    0   11   10.00000    4.95838  50.4%     -    0s
# H    0     0                       7.0000000    4.95838  29.2%     -    0s
# H    0     0                       6.0000000    4.95838  17.4%     -    0s
#      0     0     cutoff    0         6.00000    6.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 1
#   GUB cover: 2
#   RLT: 3
#
# Explored 1 nodes (448 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 6 7 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# Solution 0 has objective 6
# Solution 1 has objective 7
# Solution 2 has objective 10
#
# ----------------------------------------------------------------
#
#
#
#  instnce 9
# --------------------
# Set parameter Presolve to value 0
# Warning: constraint name "memory capacity constraints1" has a space
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0x4658e50c
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 11.0000000
# Variable types: 0 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 3.826006e+00, 342 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.82601    0   11   11.00000    3.82601  65.2%     -    0s
# H    0     0                       5.0000000    3.82601  23.5%     -    0s
#      0     0     cutoff    0         5.00000    5.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 3
#   GUB cover: 1
#   RLT: 3
#
# Explored 1 nodes (423 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000000000e+00, best bound 5.000000000000e+00, gap 0.0000%
# Solution 0 has objective 5
# Solution 1 has objective 11
#
# ----------------------------------------------------------------

# %%
def result(): 
    # Function for printing values of nonzero variables
    model.optimize()
    fixed = model.fixed()
    fixed.Params.Presolve = 0
    fixed.optimize()
    for v in fixed.getVars():
        if v.X != 0:
            i = 0
            answer = ''
            if v.VarName[0] != 'y':
                if len(v.VarName) == 7:
                    if v.Varname[3] != '_':
                        i += 1
                        print('job',v.VarName[2:4],'is assigned to machine', v.VarName[5:len(v.VarName)])
                    else:
                        i += 1
                        print('job',v.VarName[2],'is assigned to machine', v.VarName[5:len(v.VarName)])
            
            
                if len(v.VarName) == 6:
                    if v.VarName[4] != '_':
                        i += 1
                        print('job',v.VarName[2],'is assigned to machine', v.VarName[4:len(v.VarName)])
                    else:
                        i += 1
                        print('job',v.VarName[2:4],'is assigned to machine', v.VarName[len(v.VarName)-1])
            
            
                if len(v.VarName) == 5:
                    i += 1
                    print('job',v.VarName[2],'is assigned to machine',v.VarName[len(v.VarName)-1])
    model.printAttr('ObjVal')

# %%
result() # result of the optimization
# Out:
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0x4658e50c
# Variable types: 0 continuous, 240 integer (240 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Continuing optimization...
#
#
# Cutting planes:
#   Gomory: 2
#   MIR: 3
#   GUB cover: 1
#   RLT: 3
#
# Explored 1 nodes (423 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000000000e+00, best bound 5.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 270 rows, 240 columns and 1155 nonzeros
# Model fingerprint: 0x46488a7b
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.000000000e+00
# job 1 is assigned to machine 13
# job 2 is assigned to machine 4
# job 3 is assigned to machine 15
# job 4 is assigned to machine 2
# job 5 is assigned to machine 13
# job 6 is assigned to machine 2
# job 7 is assigned to machine 15
# job 8 is assigned to machine 2
# job 9 is assigned to machine 4
# job 10 is assigned to machine 13
# job 11 is assigned to machine 4
# job 12 is assigned to machine 4
# job 13 is assigned to machine 5
# job 14 is assigned to machine 5
# job 15 is assigned to machine 15
#
#       ObjVal
# ------------
#            5

# %% [markdown]
# ## relaxation:

# %%
def Model_2( number_of_instance , m , p , r , P , R , n ):
    global model, x_vars , y_vars , run_time
    model_2 = gp.Model("q1_instance_"+str(number_of_instance))
    x_vars = {}
    y_vars = {}
    start = time()
    for i in range(n):
        for j in range(m):
            x_vars[i,j] = 0 
    for i in range(m):
        y_vars [i] = 0
    constructVars() 
    contructConstrs()
    constructObj() 
    model.write('test.lp')
    model.optimize()
    model.relax()

# %%
for i in range(10):
    number_of_instance = i
    m , p , r = instance_data( number_of_instance )
    P,R,n = read_data()
    print('\n instnce '+str(number_of_instance)+'\n--------------------')
    Model_2( number_of_instance , m , p , r , P , R , n)
    print((model.MIPGap))
    print('\n----------------------------------------------------------------\n\n')
# Out:
#  instnce 0
# --------------------
# Warning: variables 0 and 240 have the same name "x_1_1"
# Warning: constraint name "memory capacity constraints1" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 8910 rows, 7920 columns and 38115 nonzeros
# Model fingerprint: 0xc3b415ba
# Variable types: 0 continuous, 7920 integer (7920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 10 (0.01s)
# MIP start from previous solve produced solution with objective 8 (0.02s)
# MIP start from previous solve produced solution with objective 7 (0.02s)
# Loaded MIP start from previous solve with objective 7
#
# Variable types: 0 continuous, 7920 integer (7920 binary)
#
# Root relaxation: objective 5.508200e+00, 4622 iterations, 0.04 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    5.50820    0   13    7.00000    5.50820  21.3%     -    0s
# <ipython-input-19-efbe00530e1c>:13: DeprecationWarning: Deprecated, pass a TempConstr or use Model.addLConstr
#   contructConstrs()
# Cutting planes:
#   Gomory: 6
#   MIR: 1
#   GUB cover: 6
#   RLT: 5
#
# Explored 1 nodes (8535 simplex iterations) in 0.20 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 7 8 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# 0.0
#
# ----------------------------------------------------------------
#
#
#
#  instnce 1
# --------------------
# Warning: variables 0 and 240 have the same name "x_1_1"
# Warning: constraint name "memory capacity constraints1" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 9180 rows, 8160 columns and 39270 nonzeros
# Model fingerprint: 0x626cc115
# Variable types: 0 continuous, 8160 integer (8160 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 6 (0.01s)
# Loaded MIP start from previous solve with objective 6
#
# Variable types: 0 continuous, 8160 integer (8160 binary)
#
# Root relaxation: cutoff, 4388 iterations, 0.04 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         6.00000    6.00000  0.00%     -    0s
#
# Explored 1 nodes (4388 simplex iterations) in 0.06 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# 0.0
#
# ----------------------------------------------------------------
#
#
#
#  instnce 2
# --------------------
# Warning: variables 0 and 240 have the same name "x_1_1"
# Warning: constraint name "memory capacity constraints1" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 9450 rows, 8400 columns and 40425 nonzeros
# Model fingerprint: 0x5296fffd
# Variable types: 0 continuous, 8400 integer (8400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 6 (0.01s)
# Loaded MIP start from previous solve with objective 6
#
# Variable types: 0 continuous, 8400 integer (8400 binary)
#
# Root relaxation: cutoff, 4732 iterations, 0.04 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         6.00000    6.00000  0.00%     -    0s
#
# Explored 1 nodes (4732 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# 0.0
#
# ----------------------------------------------------------------
#
#
#
#  instnce 3
# --------------------
# Warning: variables 0 and 240 have the same name "x_1_1"
# Warning: constraint name "memory capacity constraints1" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 9720 rows, 8640 columns and 41580 nonzeros
# Model fingerprint: 0x9adfda06
# Variable types: 0 continuous, 8640 integer (8640 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 6 (0.01s)
# Loaded MIP start from previous solve with objective 6
#
# Variable types: 0 continuous, 8640 integer (8640 binary)
#
# Root relaxation: objective 4.911429e+00, 4785 iterations, 0.04 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.91143    0   11    6.00000    4.91143  18.1%     -    0s
#
# Cutting planes:
#   Gomory: 9
#   MIR: 1
#   GUB cover: 3
#   RLT: 3
#
# Explored 1 nodes (9234 simplex iterations) in 0.21 seconds (0.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# 0.0
#
# ----------------------------------------------------------------
#
#
#
#  instnce 4
# --------------------
# Warning: variables 0 and 240 have the same name "x_1_1"
# Warning: constraint name "memory capacity constraints1" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 9990 rows, 8880 columns and 42735 nonzeros
# Model fingerprint: 0xa3aaacdf
# Variable types: 0 continuous, 8880 integer (8880 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 8 (0.01s)
# Loaded MIP start from previous solve with objective 8
#
# Variable types: 0 continuous, 8880 integer (8880 binary)
#
# Root relaxation: objective 6.278605e+00, 5163 iterations, 0.05 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    6.27860    0   12    8.00000    6.27860  21.5%     -    0s
#
# Cutting planes:
#   Gomory: 9
#   MIR: 4
#   GUB cover: 4
#   RLT: 2
#
# Explored 1 nodes (9607 simplex iterations) in 0.22 seconds (0.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+00, best bound 8.000000000000e+00, gap 0.0000%
# 0.0
#
# ----------------------------------------------------------------
#
#
#
#  instnce 5
# --------------------
# Warning: variables 0 and 240 have the same name "x_1_1"
# Warning: constraint name "memory capacity constraints1" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 10260 rows, 9120 columns and 43890 nonzeros
# Model fingerprint: 0xe6a91569
# Variable types: 0 continuous, 9120 integer (9120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 6 (0.01s)
# Loaded MIP start from previous solve with objective 6
#
# Variable types: 0 continuous, 9120 integer (9120 binary)
#
# Root relaxation: objective 4.679127e+00, 5056 iterations, 0.05 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.67913    0   11    6.00000    4.67913  22.0%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 3
#   GUB cover: 2
#   RLT: 4
#
# Explored 1 nodes (9229 simplex iterations) in 0.22 seconds (0.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# 0.0
#
# ----------------------------------------------------------------
#
#
#
#  instnce 6
# --------------------
# Warning: variables 0 and 240 have the same name "x_1_1"
# Warning: constraint name "memory capacity constraints1" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 10530 rows, 9360 columns and 45045 nonzeros
# Model fingerprint: 0xf3be30f7
# Variable types: 0 continuous, 9360 integer (9360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 6 (0.01s)
# MIP start from previous solve produced solution with objective 5 (0.02s)
# MIP start from previous solve produced solution with objective 4 (0.02s)
# Loaded MIP start from previous solve with objective 4
#
# Variable types: 0 continuous, 9360 integer (9360 binary)
#
# Root relaxation: objective 2.991754e+00, 5464 iterations, 0.05 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.99175    0   15    4.00000    2.99175  25.2%     -    0s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 2
#   GUB cover: 3
#   RLT: 4
#
# Explored 1 nodes (11297 simplex iterations) in 0.25 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4 5 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# 0.0
#
# ----------------------------------------------------------------
#
#
#
#  instnce 7
# --------------------
# Warning: variables 0 and 240 have the same name "x_1_1"
# Warning: constraint name "memory capacity constraints1" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 10800 rows, 9600 columns and 46200 nonzeros
# Model fingerprint: 0x846d4dc2
# Variable types: 0 continuous, 9600 integer (9600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 8 (0.01s)
# MIP start from previous solve produced solution with objective 7 (0.02s)
# Loaded MIP start from previous solve with objective 7
#
# Variable types: 0 continuous, 9600 integer (9600 binary)
#
# Root relaxation: objective 4.934549e+00, 5156 iterations, 0.05 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.93455    0   11    7.00000    4.93455  29.5%     -    0s
#      0     0     cutoff    0         7.00000    7.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 2
#   GUB cover: 4
#   RLT: 3
#
# Explored 1 nodes (9632 simplex iterations) in 0.24 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# 0.0
#
# ----------------------------------------------------------------
#
#
#
#  instnce 8
# --------------------
# Warning: variables 0 and 240 have the same name "x_1_1"
# Warning: constraint name "memory capacity constraints1" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 11070 rows, 9840 columns and 47355 nonzeros
# Model fingerprint: 0xfa44c354
# Variable types: 0 continuous, 9840 integer (9840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 6 (0.01s)
# Loaded MIP start from previous solve with objective 6
#
# Variable types: 0 continuous, 9840 integer (9840 binary)
#
# Root relaxation: objective 4.958384e+00, 5372 iterations, 0.05 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.95838    0   11    6.00000    4.95838  17.4%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 3
#   GUB cover: 2
#   RLT: 3
#
# Explored 1 nodes (9993 simplex iterations) in 0.24 seconds (0.20 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# 0.0
#
# ----------------------------------------------------------------
#
#
#
#  instnce 9
# --------------------
# Warning: variables 0 and 240 have the same name "x_1_1"
# Warning: constraint name "memory capacity constraints1" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 11340 rows, 10080 columns and 48510 nonzeros
# Model fingerprint: 0xf981f18d
# Variable types: 0 continuous, 10080 integer (10080 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5 (0.01s)
# Loaded MIP start from previous solve with objective 5
#
# Variable types: 0 continuous, 10080 integer (10080 binary)
#
# Root relaxation: objective 3.826006e+00, 5734 iterations, 0.06 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.82601    0   12    5.00000    3.82601  23.5%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 4
#   RLT: 3
#
# Explored 1 nodes (10453 simplex iterations) in 0.25 seconds (0.20 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000000000e+00, best bound 5.000000000000e+00, gap 0.0000%
# 0.0
#
# ----------------------------------------------------------------

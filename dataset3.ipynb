# %%
# %matplotlib inline
# !pip install gurobipy

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
import gurobipy as gp
from gurobipy import GRB
from time import time


def read_data():
    data = pd.read_csv('constants.csv')
    P = data['value'][0]
    R = data['value'][1]
    n = data['value'][2]
    return (P,R,n)

def instance_data(number_of_instance):
    instance = pd.read_csv('instance_'+str(number_of_instance)+'.csv')
    m = instance.shape[0]
    p = []
    r = []
    for p_i in instance['p_i']:
        p.append(p_i)
    for r_i in instance['r_i']:
        r.append(r_i)
    return (m,p,r)

def Model( number_of_instance , m , p , r , P , R , n ):
    global model, x_vars , y_vars , run_time
    model = gp.Model("q1_instance_"+str(number_of_instance))
    x_vars = {}
    y_vars = {}
    start = time()
    for i in range(n):
        for j in range(m):
            x_vars[i,j] = 0 
    for i in range(m):
        y_vars [i] = 0
    constructVars() 
    contructConstrs()
    constructObj() 
    model.write('test.lp')
    model.optimize()
    model.printAttr('X')
    #model.printAttr('Xn')
    model.printAttr('ObjVal')
    model.printAttr('runtime')
    model.printAttr('NodeCount')
    print(f'Time taken to run: {time() - start} seconds')

def constructVars(): 
    global n , m , model, x_vars ,y_vars
    
    for i in range( m ): 
        for j in range( n ): 
            var = model.addVar( vtype = GRB.BINARY , name = "x_" + str( i ) + "_" + str( j ) ) 
            x_vars[ i , j ] = var 
    model.update()
    
    for j in range( n ):
        var_2 = model.addVar( vtype = GRB.BINARY , name = "y_" + str( j )) 
        y_vars[ j ] = var_2
    model.update()

def contructConstrs(): 
    global n , m , model , x_vars , y_vars , P , R
    
    for i in range( m ): 
        constExpr_0 = gp.LinExpr() 
        for j in range( n ): 
            constExpr_0 += 1.0 * x_vars[ i,j ] 
        model.addLConstr( lhs = constExpr_0 , sense = GRB.EQUAL , rhs = '1' ) 
    model.update()
    
    for i in range( m ):
        constExpr_1_1 = gp.LinExpr()
        constExpr_1_2 = gp.LinExpr()
        for j in range( n ):
            constExpr_1_1 = 1.0 * x_vars[i,j]
            constExpr_1_2 = 1.0 * y_vars[j]
            model.addLConstr(lhs= constExpr_1_1, sense = GRB.LESS_EQUAL , rhs = constExpr_1_2)
    model.update()
    
    for j in range( n ):
        constExpr_2 = gp.LinExpr()
        rhs_exp = gp.LinExpr()
        for i in range( m ): 
            constExpr_2 += p[j] * x_vars[ i,j ]
            rhs_exp = P * y_vars[j] 
        model.addLConstr( lhs = constExpr_2 , sense = GRB.LESS_EQUAL , rhs = rhs_exp  ) 
    model.update()
    
    for j in range( n ):
        constExpr_3 = gp.LinExpr()
        rhs_exp = gp.LinExpr()
        for i in range( m ): 
            constExpr_3 += r[j] * x_vars[ i,j ]
            rhs_exp_3 = R * y_vars[j] 
        model.addLConstr( lhs = constExpr_3 , sense = GRB.LESS_EQUAL , rhs = rhs_exp_3  ) 
    model.update()

def constructObj(): 
    global m , n , model , x_vars , y_vars
    objExpr = gp.LinExpr()
    for j in range( n ):
        objExpr += y_vars[j]
    model.setObjective( objExpr , GRB.MINIMIZE ) 
    model.update()

def processing_result(): #source: Gurobi website (https://www.gurobi.com/documentation/9.5/examples/mip2_py.html)
    if len(sys.argv) < 2:
        print('Usage: mip2.py filename')
        sys.exit(0)

    # Read and solve model

    if model.IsMIP == 0:
        print('Model is not a MIP')
        sys.exit(0)

    model.optimize()

    if model.Status == GRB.OPTIMAL:
        print('Optimal objective: %g' % model.ObjVal)
    elif model.Status == GRB.INF_OR_UNBD:
        print('Model is infeasible or unbounded')
        sys.exit(0)
    elif model.Status == GRB.INFEASIBLE:
        print('Model is infeasible')
        sys.exit(0)
    elif model.Status == GRB.UNBOUNDED:
        print('Model is unbounded')
        sys.exit(0)
    else:
        print('Optimization ended with status %d' % model.Status)
        sys.exit(0)

    # Iterate over the solutions and compute the objectives
    model.Params.OutputFlag = 0
    print('')
    for k in range(model.SolCount):
        model.Params.SolutionNumber = k
        print('Solution %d has objective %g' % (k, model.PoolObjVal))
    print('')
    model.Params.OutputFlag = 1

    fixed = model.fixed()
    fixed.Params.Presolve = 0
    fixed.optimize()

    if fixed.Status != GRB.OPTIMAL:
        print("Error: fixed model isn't optimal")
        sys.exit(1)
        
    diff = model.ObjVal - fixed.ObjVal

    if abs(diff) > 1e-6 * (1.0 + abs(model.ObjVal)):
        print('Error: objective values are different')
        sys.exit(1)

#def result(): 
    # Function for printing values of nonzero variables
    #model.optimize()
    #fixed = model.fixed()
    #fixed.Params.Presolve = 0
    #fixed.optimize()
    #for v in model.getVars():
        #if v.X != 0:
            #i = 0
            #answer = ''
            #if v.VarName[0] != 'y':
                #if len(v.VarName) == 7:
                    #if v.Varname[3] != '_':
                        #i += 1
                        #print('job',v.VarName[2:4],'is assigned to machine', v.VarName[5:len(v.VarName)])
                    #else:
                        #i += 1
                        #print('job',v.VarName[2],'is assigned to machine', v.VarName[5:len(v.VarName)])
            
            
                #if len(v.VarName) == 6:
                    #if v.VarName[4] != '_':
                        #i += 1
                        #print('job',v.VarName[2],'is assigned to machine', v.VarName[4:len(v.VarName)])
                    #else:
                        #i += 1
                        #print('job',v.VarName[2:4],'is assigned to machine', v.VarName[len(v.VarName)-1])
            
            
                #if len(v.VarName) == 5:
                    #i += 1
                    #print('job',v.VarName[2],'is assigned to machine',v.VarName[len(v.VarName)-1])

#result() # result of the optimization

runtime = time()
for i in range(10):
    number_of_instance = i
    m , p , r = instance_data( number_of_instance )
    P,R,n = read_data()
    print('\n instnce '+str(number_of_instance)+'\n--------------------')
    Model ( number_of_instance , m , p , r , P , R , n)
    print('\n----------------------------------------------------------------\n\n')
    model.printAttr('NumConstrs')
print(f'Total time taken to run all instances: {time() - runtime} seconds')
# Out:
# Requirement already satisfied: gurobipy in /Applications/anaconda3/lib/python3.8/site-packages (9.5.0)
#
#  instnce 0
# --------------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-19
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x33dd0064
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 38.0000000
# Presolve removed 1150 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 1500 rows, 2550 columns, 7850 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
#
# Root relaxation: objective 1.850000e+01, 1678 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.50000    0    9   38.00000   18.50000  51.3%     -    0s
# H    0     0                      19.0000000   18.50000  2.63%     -    0s
#      0     0   18.50000    0    9   19.00000   18.50000  2.63%     -    0s
#
# Explored 1 nodes (1678 simplex iterations) in 0.05 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 19 38
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.900000000000e+01, best bound 1.900000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#        x_0_2            1
#        x_1_9            1
#       x_2_34            1
#       x_3_32            1
#        x_4_9            1
#       x_5_27            1
#       x_6_25            1
#       x_7_39            1
#       x_8_34            1
#       x_9_43            1
#      x_10_19            1
#      x_11_43            1
#       x_12_2            1
#       x_13_2            1
#      x_14_39            1
#      x_15_25            1
#      x_16_40            1
#      x_17_34            1
#      x_18_18            1
#       x_19_1            1
#      x_20_18            1
#       x_21_2            1
#      x_22_43            1
#       x_23_2            1
#      x_24_36            1
#      x_25_33            1
#      x_26_11            1
#      x_27_42            1
#      x_28_36            1
#      x_29_43            1
#       x_30_4            1
#      x_31_43            1
#      x_32_19            1
#       x_33_2            1
#      x_34_11            1
#      x_35_13            1
#      x_36_13            1
#       x_37_1            1
#      x_38_25            1
#      x_39_20            1
#      x_40_34            1
#       x_41_9            1
#      x_42_20            1
#      x_43_33            1
#       x_44_9            1
#      x_45_27            1
#       x_46_4            1
#      x_47_32            1
#      x_48_39            1
#      x_49_42            1
#          y_1            1
#          y_2            1
#          y_4            1
#          y_9            1
#         y_11            1
#         y_13            1
#         y_18            1
#         y_19            1
#         y_20            1
#         y_25            1
#         y_27            1
#         y_32            1
#         y_33            1
#         y_34            1
#         y_36            1
#         y_39            1
#         y_40            1
#         y_42            1
#         y_43            1
#
#       ObjVal
# ------------
#           19
#
#      runtime
# ------------
#     0.051924
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.20394587516784668 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#         2650
#
#  instnce 1
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x772bbd8e
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 36.0000000
# Presolve removed 1150 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 1500 rows, 2550 columns, 7850 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
#
# Root relaxation: objective 1.550000e+01, 3020 iterations, 0.07 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   15.50000    0    5   36.00000   15.50000  56.9%     -    0s
# H    0     0                      16.0000000   15.50000  3.12%     -    0s
#      0     0   15.50000    0    5   16.00000   15.50000  3.12%     -    0s
#
# Explored 1 nodes (4217 simplex iterations) in 0.11 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 16 36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_14            1
#       x_1_15            1
#       x_2_32            1
#       x_3_32            1
#       x_4_28            1
#       x_5_31            1
#       x_6_49            1
#       x_7_37            1
#       x_8_29            1
#       x_9_43            1
#      x_10_32            1
#       x_11_8            1
#      x_12_46            1
#       x_13_1            1
#      x_14_13            1
#      x_15_25            1
#      x_16_37            1
#      x_17_46            1
#      x_18_15            1
#       x_19_1            1
#      x_20_46            1
#      x_21_49            1
#      x_22_43            1
#      x_23_31            1
#      x_24_12            1
#      x_25_28            1
#      x_26_10            1
#      x_27_29            1
#      x_28_14            1
#      x_29_43            1
#      x_30_49            1
#      x_31_29            1
#      x_32_10            1
#      x_33_32            1
#      x_34_10            1
#      x_35_13            1
#      x_36_13            1
#       x_37_8            1
#      x_38_12            1
#       x_39_8            1
#      x_40_28            1
#      x_41_12            1
#      x_42_32            1
#      x_43_37            1
#      x_44_14            1
#       x_45_1            1
#      x_46_15            1
#      x_47_49            1
#      x_48_49            1
#      x_49_28            1
#          y_1            1
#          y_8            1
#         y_10            1
#         y_12            1
#         y_13            1
#         y_14            1
#         y_15            1
#         y_25            1
#         y_28            1
#         y_29            1
#         y_31            1
#         y_32            1
#         y_37            1
#         y_43            1
#         y_46            1
#         y_49            1
#
#       ObjVal
# ------------
#           16
#
#      runtime
# ------------
#     0.114935
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.2701880931854248 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#         2650
#
#  instnce 2
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x148a7cb7
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 36.0000000
# Presolve removed 1300 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 1350 rows, 2550 columns, 7550 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
#
# Root relaxation: objective 1.750000e+01, 2880 iterations, 0.04 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   17.50000    0    7   36.00000   17.50000  51.4%     -    0s
# H    0     0                      18.0000000   17.50000  2.78%     -    0s
#      0     0   17.50000    0    7   18.00000   17.50000  2.78%     -    0s
#
# Explored 1 nodes (2880 simplex iterations) in 0.07 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 18 36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_44            1
#       x_1_19            1
#       x_2_30            1
#       x_3_40            1
#        x_4_6            1
#       x_5_39            1
#       x_6_49            1
#       x_7_43            1
#       x_8_43            1
#        x_9_1            1
#      x_10_13            1
#      x_11_46            1
#      x_12_44            1
#      x_13_19            1
#       x_14_6            1
#       x_15_4            1
#      x_16_31            1
#      x_17_13            1
#      x_18_39            1
#      x_19_30            1
#      x_20_39            1
#      x_21_22            1
#      x_22_46            1
#      x_23_49            1
#       x_24_6            1
#       x_25_6            1
#      x_26_39            1
#      x_27_31            1
#      x_28_40            1
#      x_29_41            1
#      x_30_48            1
#       x_31_1            1
#       x_32_1            1
#      x_33_41            1
#      x_34_44            1
#      x_35_49            1
#      x_36_42            1
#      x_37_30            1
#      x_38_42            1
#      x_39_41            1
#      x_40_13            1
#      x_41_22            1
#      x_42_31            1
#      x_43_22            1
#      x_44_39            1
#       x_45_6            1
#      x_46_48            1
#      x_47_18            1
#      x_48_19            1
#       x_49_4            1
#          y_1            1
#          y_4            1
#          y_6            1
#         y_13            1
#         y_18            1
#         y_19            1
#         y_22            1
#         y_30            1
#         y_31            1
#         y_39            1
#         y_40            1
#         y_41            1
#         y_42            1
#         y_43            1
#         y_44            1
#         y_46            1
#         y_48            1
#         y_49            1
#
#       ObjVal
# ------------
#           18
#
#      runtime
# ------------
#     0.068872
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.2210071086883545 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#         2650
#
#  instnce 3
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x1cd9f073
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 37.0000000
# Presolve removed 1400 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 1250 rows, 2550 columns, 7350 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
#
# Root relaxation: objective 1.600000e+01, 1841 iterations, 0.03 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      16.0000000   16.00000  0.00%     -    0s
#
# Explored 1 nodes (1841 simplex iterations) in 0.06 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 16 37
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_14            1
#        x_1_8            1
#        x_2_3            1
#       x_3_11            1
#       x_4_13            1
#        x_5_8            1
#       x_6_40            1
#       x_7_25            1
#        x_8_3            1
#       x_9_13            1
#      x_10_40            1
#      x_11_28            1
#      x_12_22            1
#      x_13_43            1
#      x_14_26            1
#      x_15_32            1
#      x_16_35            1
#      x_17_26            1
#      x_18_14            1
#      x_19_23            1
#      x_20_27            1
#      x_21_35            1
#      x_22_14            1
#      x_23_43            1
#      x_24_13            1
#      x_25_40            1
#      x_26_43            1
#       x_27_7            1
#      x_28_27            1
#      x_29_27            1
#       x_30_7            1
#      x_31_35            1
#      x_32_22            1
#      x_33_26            1
#      x_34_23            1
#      x_35_40            1
#       x_36_3            1
#      x_37_14            1
#       x_38_8            1
#      x_39_32            1
#      x_40_35            1
#      x_41_28            1
#       x_42_7            1
#      x_43_26            1
#      x_44_25            1
#      x_45_32            1
#      x_46_11            1
#      x_47_11            1
#      x_48_23            1
#      x_49_28            1
#          y_3            1
#          y_7            1
#          y_8            1
#         y_11            1
#         y_13            1
#         y_14            1
#         y_22            1
#         y_23            1
#         y_25            1
#         y_26            1
#         y_27            1
#         y_28            1
#         y_32            1
#         y_35            1
#         y_40            1
#         y_43            1
#
#       ObjVal
# ------------
#           16
#
#      runtime
# ------------
#    0.0623178
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.23680710792541504 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#         2650
#
#  instnce 4
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x09c5f269
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 36.0000000
# Presolve removed 1400 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 1250 rows, 2550 columns, 7350 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
#
# Root relaxation: objective 1.950000e+01, 1130 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   19.50000    0    7   36.00000   19.50000  45.8%     -    0s
# H    0     0                      20.0000000   19.50000  2.50%     -    0s
#      0     0   19.50000    0    7   20.00000   19.50000  2.50%     -    0s
#
# Explored 1 nodes (1130 simplex iterations) in 0.04 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 20 36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#        x_0_0            1
#        x_1_2            1
#       x_2_21            1
#       x_3_22            1
#       x_4_20            1
#       x_5_23            1
#       x_6_29            1
#       x_7_39            1
#       x_8_36            1
#        x_9_4            1
#      x_10_49            1
#      x_11_37            1
#      x_12_31            1
#       x_13_4            1
#      x_14_23            1
#      x_15_29            1
#      x_16_19            1
#      x_17_26            1
#      x_18_21            1
#      x_19_16            1
#       x_20_4            1
#       x_21_1            1
#      x_22_22            1
#      x_23_39            1
#      x_24_13            1
#      x_25_15            1
#      x_26_16            1
#       x_27_1            1
#       x_28_4            1
#      x_29_49            1
#      x_30_21            1
#      x_31_15            1
#       x_32_1            1
#      x_33_31            1
#       x_34_0            1
#      x_35_38            1
#       x_36_2            1
#      x_37_21            1
#      x_38_13            1
#      x_39_20            1
#      x_40_20            1
#      x_41_38            1
#      x_42_37            1
#      x_43_26            1
#      x_44_38            1
#      x_45_26            1
#       x_46_1            1
#       x_47_4            1
#      x_48_23            1
#      x_49_36            1
#          y_0            1
#          y_1            1
#          y_2            1
#          y_4            1
#         y_13            1
#         y_15            1
#         y_16            1
#         y_19            1
#         y_20            1
#         y_21            1
#         y_22            1
#         y_23            1
#         y_26            1
#         y_29            1
#         y_31            1
#         y_36            1
#         y_37            1
#         y_38            1
#         y_39            1
#         y_49            1
#
#       ObjVal
# ------------
#           20
#
#      runtime
# ------------
#    0.0419002
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.1960899829864502 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#         2650
#
#  instnce 5
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x5edf8905
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 36.0000000
# Presolve removed 1400 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 1250 rows, 2550 columns, 7350 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
#
# Root relaxation: objective 1.850000e+01, 2493 iterations, 0.03 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.50000    0    7   36.00000   18.50000  48.6%     -    0s
# H    0     0                      19.0000000   18.50000  2.63%     -    0s
#      0     0   18.50000    0    7   19.00000   18.50000  2.63%     -    0s
#
# Explored 1 nodes (2493 simplex iterations) in 0.06 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 19 36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.900000000000e+01, best bound 1.900000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_15            1
#       x_1_44            1
#       x_2_42            1
#       x_3_48            1
#       x_4_42            1
#       x_5_44            1
#        x_6_4            1
#       x_7_16            1
#       x_8_36            1
#        x_9_7            1
#      x_10_23            1
#      x_11_44            1
#       x_12_0            1
#       x_13_4            1
#      x_14_33            1
#      x_15_32            1
#      x_16_47            1
#      x_17_26            1
#      x_18_49            1
#      x_19_33            1
#      x_20_49            1
#      x_21_46            1
#      x_22_22            1
#      x_23_48            1
#      x_24_47            1
#      x_25_10            1
#      x_26_16            1
#       x_27_7            1
#      x_28_46            1
#      x_29_44            1
#       x_30_7            1
#      x_31_46            1
#      x_32_44            1
#      x_33_16            1
#       x_34_0            1
#      x_35_33            1
#      x_36_46            1
#      x_37_10            1
#      x_38_22            1
#      x_39_32            1
#      x_40_15            1
#      x_41_38            1
#      x_42_48            1
#      x_43_26            1
#      x_44_38            1
#      x_45_32            1
#      x_46_26            1
#      x_47_46            1
#      x_48_26            1
#      x_49_36            1
#          y_0            1
#          y_4            1
#          y_7            1
#         y_10            1
#         y_15            1
#         y_16            1
#         y_22            1
#         y_23            1
#         y_26            1
#         y_32            1
#         y_33            1
#         y_36            1
#         y_38            1
#         y_42            1
#         y_44            1
#         y_46            1
#         y_47            1
#         y_48            1
#         y_49            1
#
#       ObjVal
# ------------
#           19
#
#      runtime
# ------------
#     0.059993
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.21395087242126465 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#         2650
#
#  instnce 6
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0xa7cfcc38
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 35.0000000
# Presolve removed 1100 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 1550 rows, 2550 columns, 7950 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
#
# Root relaxation: objective 1.500000e+01, 3314 iterations, 0.07 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      15.0000000   15.00000  0.00%     -    0s
#
# Explored 1 nodes (3314 simplex iterations) in 0.11 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 15 35
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#        x_0_0            1
#       x_1_47            1
#       x_2_14            1
#       x_3_30            1
#        x_4_0            1
#       x_5_22            1
#        x_6_9            1
#       x_7_33            1
#       x_8_33            1
#        x_9_9            1
#      x_10_39            1
#      x_11_14            1
#      x_12_35            1
#       x_13_9            1
#       x_14_3            1
#      x_15_39            1
#       x_16_3            1
#       x_17_3            1
#      x_18_46            1
#      x_19_39            1
#      x_20_46            1
#      x_21_33            1
#      x_22_46            1
#       x_23_2            1
#      x_24_20            1
#       x_25_5            1
#       x_26_5            1
#      x_27_35            1
#      x_28_47            1
#      x_29_38            1
#      x_30_46            1
#       x_31_2            1
#      x_32_47            1
#      x_33_38            1
#      x_34_22            1
#      x_35_20            1
#       x_36_2            1
#      x_37_35            1
#      x_38_38            1
#      x_39_30            1
#       x_40_9            1
#      x_41_33            1
#       x_42_5            1
#       x_43_3            1
#      x_44_30            1
#      x_45_46            1
#      x_46_46            1
#      x_47_33            1
#      x_48_22            1
#       x_49_0            1
#          y_0            1
#          y_2            1
#          y_3            1
#          y_5            1
#          y_9            1
#         y_14            1
#         y_20            1
#         y_22            1
#         y_30            1
#         y_33            1
#         y_35            1
#         y_38            1
#         y_39            1
#         y_46            1
#         y_47            1
#
#       ObjVal
# ------------
#           15
#
#      runtime
# ------------
#     0.112633
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.26505088806152344 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#         2650
#
#  instnce 7
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x351b05d5
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 36.0000000
# Presolve removed 950 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 1700 rows, 2550 columns, 8250 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
#
# Root relaxation: objective 1.250000e+01, 3477 iterations, 0.08 seconds (0.16 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.50000    0    7   36.00000   12.50000  65.3%     -    0s
# H    0     0                      13.0000000   12.50000  3.85%     -    0s
#      0     0   12.50000    0    7   13.00000   12.50000  3.85%     -    0s
#
# Explored 1 nodes (3477 simplex iterations) in 0.11 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 13 36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#        x_0_3            1
#       x_1_43            1
#        x_2_3            1
#       x_3_15            1
#       x_4_20            1
#        x_5_9            1
#       x_6_48            1
#        x_7_3            1
#        x_8_3            1
#       x_9_43            1
#      x_10_48            1
#       x_11_9            1
#      x_12_23            1
#      x_13_15            1
#      x_14_47            1
#       x_15_8            1
#      x_16_41            1
#       x_17_9            1
#      x_18_31            1
#      x_19_31            1
#      x_20_23            1
#      x_21_47            1
#       x_22_8            1
#      x_23_36            1
#      x_24_15            1
#      x_25_23            1
#       x_26_3            1
#      x_27_15            1
#      x_28_15            1
#      x_29_48            1
#       x_30_0            1
#      x_31_47            1
#      x_32_31            1
#      x_33_41            1
#       x_34_3            1
#      x_35_43            1
#      x_36_20            1
#      x_37_36            1
#      x_38_20            1
#      x_39_41            1
#      x_40_15            1
#      x_41_20            1
#      x_42_48            1
#      x_43_36            1
#      x_44_36            1
#      x_45_20            1
#      x_46_48            1
#      x_47_36            1
#       x_48_9            1
#       x_49_3            1
#          y_0            1
#          y_3            1
#          y_8            1
#          y_9            1
#         y_15            1
#         y_20            1
#         y_23            1
#         y_31            1
#         y_36            1
#         y_41            1
#         y_43            1
#         y_47            1
#         y_48            1
#
#       ObjVal
# ------------
#           13
#
#      runtime
# ------------
#     0.116598
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.27149510383605957 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#         2650
#
#  instnce 8
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0xc1146d60
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 37.0000000
# Presolve removed 1300 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 1350 rows, 2550 columns, 7550 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
#
# Root relaxation: objective 2.050000e+01, 1361 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   20.50000    0    5   37.00000   20.50000  44.6%     -    0s
# H    0     0                      21.0000000   20.50000  2.38%     -    0s
#      0     0   20.50000    0    5   21.00000   20.50000  2.38%     -    0s
#
# Explored 1 nodes (2303 simplex iterations) in 0.05 seconds (0.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 21 37
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.100000000000e+01, best bound 2.100000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#        x_0_8            1
#       x_1_46            1
#        x_2_8            1
#       x_3_26            1
#       x_4_26            1
#       x_5_39            1
#        x_6_6            1
#       x_7_14            1
#        x_8_1            1
#        x_9_1            1
#      x_10_13            1
#      x_11_12            1
#      x_12_44            1
#      x_13_38            1
#      x_14_28            1
#      x_15_23            1
#      x_16_31            1
#      x_17_13            1
#      x_18_35            1
#      x_19_30            1
#      x_20_46            1
#      x_21_38            1
#       x_22_4            1
#      x_23_31            1
#       x_24_6            1
#      x_25_21            1
#      x_26_28            1
#      x_27_31            1
#      x_28_40            1
#      x_29_14            1
#       x_30_9            1
#      x_31_23            1
#      x_32_12            1
#      x_33_13            1
#      x_34_35            1
#      x_35_21            1
#      x_36_12            1
#      x_37_30            1
#       x_38_4            1
#      x_39_44            1
#      x_40_28            1
#      x_41_22            1
#      x_42_28            1
#      x_43_22            1
#      x_44_39            1
#      x_45_28            1
#      x_46_12            1
#      x_47_40            1
#      x_48_14            1
#      x_49_14            1
#          y_1            1
#          y_4            1
#          y_6            1
#          y_8            1
#          y_9            1
#         y_12            1
#         y_13            1
#         y_14            1
#         y_21            1
#         y_22            1
#         y_23            1
#         y_26            1
#         y_28            1
#         y_30            1
#         y_31            1
#         y_35            1
#         y_38            1
#         y_39            1
#         y_40            1
#         y_44            1
#         y_46            1
#
#       ObjVal
# ------------
#           21
#
#      runtime
# ------------
#     0.055254
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.22385406494140625 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#         2650
#
#  instnce 9
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0xf3525fa9
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 36.0000000
# Presolve removed 1350 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 1300 rows, 2550 columns, 7450 nonzeros
# Variable types: 0 continuous, 2550 integer (2550 binary)
#
# Root relaxation: objective 1.900000e+01, 2404 iterations, 0.05 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      19.0000000   19.00000  0.00%     -    0s
#
# Explored 1 nodes (2404 simplex iterations) in 0.08 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 19 36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.900000000000e+01, best bound 1.900000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#        x_0_3            1
#        x_1_4            1
#        x_2_8            1
#        x_3_1            1
#        x_4_8            1
#       x_5_39            1
#       x_6_32            1
#       x_7_15            1
#       x_8_28            1
#       x_9_27            1
#      x_10_22            1
#      x_11_41            1
#      x_12_47            1
#       x_13_1            1
#      x_14_15            1
#      x_15_41            1
#      x_16_39            1
#      x_17_13            1
#      x_18_14            1
#       x_19_2            1
#      x_20_13            1
#      x_21_47            1
#       x_22_4            1
#      x_23_43            1
#      x_24_45            1
#      x_25_27            1
#      x_26_43            1
#      x_27_36            1
#       x_28_4            1
#      x_29_39            1
#      x_30_28            1
#      x_31_15            1
#      x_32_12            1
#      x_33_15            1
#      x_34_45            1
#      x_35_12            1
#      x_36_15            1
#       x_37_4            1
#      x_38_39            1
#      x_39_39            1
#      x_40_14            1
#      x_41_22            1
#      x_42_32            1
#       x_43_2            1
#       x_44_2            1
#       x_45_3            1
#      x_46_36            1
#       x_47_2            1
#      x_48_39            1
#       x_49_3            1
#          y_1            1
#          y_2            1
#          y_3            1
#          y_4            1
#          y_8            1
#         y_12            1
#         y_13            1
#         y_14            1
#         y_15            1
#         y_22            1
#         y_27            1
#         y_28            1
#         y_32            1
#         y_36            1
#         y_39            1
#         y_41            1
#         y_43            1
#         y_45            1
#         y_47            1
#
#       ObjVal
# ------------
#           19
#
#      runtime
# ------------
#    0.0771549
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.2310338020324707 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#         2650
# Total time taken to run all instances: 2.395751953125 seconds

# %% [markdown]
# ## Relaxation:

# %%
def contructConstrs(): 
    global n , m , model_2 , x_vars , y_vars , P , R
    
    for i in range( m ): 
        constExpr_0 = gp.LinExpr() 
        for j in range( n ): 
            constExpr_0 += 1.0 * x_vars[ i,j ] 
        model_2.addLConstr( lhs = constExpr_0 , sense = GRB.EQUAL , rhs = '1' ) 
    model_2.update()
    
    for i in range( m ):
        constExpr_1_1 = gp.LinExpr()
        constExpr_1_2 = gp.LinExpr()
        for j in range( n ):
            constExpr_1_1 = 1.0 * x_vars[i,j]
            constExpr_1_2 = 1.0 * y_vars[j]
            model_2.addLConstr(lhs= constExpr_1_1, sense = GRB.LESS_EQUAL , rhs = constExpr_1_2)
    model_2.update()
    
    for j in range( n ):
        constExpr_2 = gp.LinExpr()
        rhs_exp = gp.LinExpr()
        for i in range( m ): 
            constExpr_2 += p[j] * x_vars[ i,j ]
            rhs_exp = P * y_vars[j] 
        model_2.addLConstr( lhs = constExpr_2 , sense = GRB.LESS_EQUAL , rhs = rhs_exp  ) 
    model_2.update()
    
    for j in range( n ):
        constExpr_3 = gp.LinExpr()
        rhs_exp = gp.LinExpr()
        for i in range( m ): 
            constExpr_3 += r[j] * x_vars[ i,j ]
            rhs_exp_3 = R * y_vars[j] 
        model_2.addLConstr( lhs = constExpr_3 , sense = GRB.LESS_EQUAL , rhs = rhs_exp_3  ) 
    model_2.update()
    
    
def constructVars_relax(): 
    global n , m , model_2, x_vars ,y_vars
    
    for i in range( m ): 
        for j in range( n ): 
            var = model_2.addVar( vtype = GRB.CONTINUOUS , name = "x_" + str( i ) + "_" + str( j ) ) 
            x_vars[ i , j ] = var 
    model_2.update()
    
    for j in range( n ):
        var_2 = model_2.addVar( vtype = GRB.CONTINUOUS , name = "y_" + str( j )) 
        y_vars[ j ] = var_2
    model_2.update()

def constructObj(): 
    global m , n , model_2 , x_vars , y_vars
    objExpr = gp.LinExpr()
    for j in range( n ):
        objExpr += y_vars[j]
    model_2.setObjective( objExpr , GRB.MINIMIZE ) 
    model_2.update()
    
def Model( number_of_instance , m , p , r , P , R , n ):
    global model_2, x_vars , y_vars , run_time
    model_2 = gp.Model("q1_instance_"+str(number_of_instance))
    x_vars = {}
    y_vars = {}
    start = time()
    for i in range(n):
        for j in range(m):
            x_vars[i,j] = 0 
    for i in range(m):
        y_vars [i] = 0
    constructVars_relax() 
    contructConstrs()
    constructObj() 
    model_2.write('test.lp')
    model_2.optimize()
    model_2.printAttr('X')
    #model.printAttr('Xn')
    model_2.printAttr('ObjVal')
    model_2.printAttr('runtime')
    model_2.printAttr('NodeCount')
    print(f'Time taken to run: {time() - start} seconds')

runtime = time()
for i in range(10):
    number_of_instance = i
    m , p , r = instance_data( number_of_instance )
    P,R,n = read_data()
    print('\n instnce '+str(number_of_instance)+'\n--------------------')
    Model ( number_of_instance , m , p , r , P , R , n)
    print('\n----------------------------------------------------------------\n\n')

print(f'Total time taken to run all instances: {time() - runtime} seconds')
# Out:
#  instnce 0
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0xb998cd5f
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2649 rows, 2550 columns, 12549 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.709375e+01   0.000000e+00      0s
#       52    8.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       50 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.7755576e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      105    8.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 105 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  8.000000000e+00
#
#     Variable            X
# -------------------------
#        x_0_2            1
#        x_1_2            1
#        x_2_2            1
#        x_3_2            1
#        x_4_2            1
#        x_5_2            1
#        x_6_2            1
#        x_7_2            1
#        x_8_2            1
#        x_9_2            1
#       x_10_2            1
#       x_11_2            1
#       x_12_2            1
#       x_13_2            1
#       x_14_2            1
#       x_15_2            1
#       x_16_2            1
#       x_17_2            1
#       x_18_2            1
#       x_19_2            1
#       x_20_2            1
#       x_21_2            1
#       x_22_2            1
#       x_23_2            1
#       x_24_2            1
#       x_25_2            1
#       x_26_2            1
#       x_27_2            1
#       x_28_2            1
#       x_29_2            1
#       x_30_2            1
#       x_31_2            1
#       x_32_2            1
#       x_33_2            1
#       x_34_2            1
#       x_35_2            1
#       x_36_2            1
#       x_37_2            1
#       x_38_2            1
#       x_39_2            1
#       x_40_2            1
#       x_41_2            1
#       x_42_2            1
#       x_43_2            1
#       x_44_2            1
#       x_45_2            1
#       x_46_2            1
#       x_47_2            1
#       x_48_2            1
#       x_49_2            1
#          y_2            8
#
#       ObjVal
# ------------
#            8
#
#      runtime
# ------------
#    0.0148351
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.16708803176879883 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 1
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x80835aa8
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2649 rows, 2550 columns, 12549 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.818750e+01   0.000000e+00      0s
#       50    9.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       49 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.4286129e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      102    9.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 102 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  9.000000000e+00
#
#     Variable            X
# -------------------------
#       x_0_49            1
#       x_1_49            1
#       x_2_49            1
#       x_3_49            1
#       x_4_49            1
#       x_5_49            1
#       x_6_49            1
#       x_7_49            1
#       x_8_49            1
#       x_9_49            1
#      x_10_49            1
#      x_11_49            1
#      x_12_49            1
#      x_13_49            1
#      x_14_49            1
#      x_15_49            1
#      x_16_49            1
#      x_17_49            1
#      x_18_49            1
#      x_19_49            1
#      x_20_49            1
#      x_21_49            1
#      x_22_49            1
#      x_23_49            1
#      x_24_49            1
#      x_25_49            1
#      x_26_49            1
#      x_27_49            1
#      x_28_49            1
#      x_29_49            1
#      x_30_49            1
#      x_31_49            1
#      x_32_49            1
#      x_33_49            1
#      x_34_49            1
#      x_35_49            1
#      x_36_49            1
#      x_37_49            1
#      x_38_49            1
#      x_39_49            1
#      x_40_49            1
#      x_41_49            1
#      x_42_49            1
#      x_43_49            1
#      x_44_49            1
#      x_45_49            1
#      x_46_49            1
#      x_47_49            1
#      x_48_49            1
#      x_49_49            1
#         y_49            9
#
#       ObjVal
# ------------
#            9
#
#      runtime
# ------------
#    0.0134568
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.16254711151123047 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 2
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x0b587a93
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2648 rows, 2550 columns, 12498 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.131250e+01   0.000000e+00      0s
#       54    9.3333333e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       50 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.9388939e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      107    9.3333333e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 107 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  9.333333333e+00
#
#     Variable            X
# -------------------------
#        x_0_6            1
#        x_1_6            1
#        x_2_6            1
#        x_3_6            1
#        x_4_6            1
#        x_5_6            1
#        x_6_6            1
#        x_7_6            1
#        x_8_6            1
#        x_9_6            1
#       x_10_6            1
#       x_11_6            1
#       x_12_6            1
#       x_13_6            1
#       x_14_6            1
#       x_15_6            1
#       x_16_6            1
#       x_17_6            1
#       x_18_6            1
#       x_19_6            1
#       x_20_6            1
#       x_21_6            1
#       x_22_6            1
#       x_23_6            1
#       x_24_6            1
#       x_25_6            1
#       x_26_6            1
#       x_27_6            1
#       x_28_6            1
#       x_29_6            1
#       x_30_6            1
#       x_31_6            1
#       x_32_6            1
#       x_33_6            1
#       x_34_6            1
#       x_35_6            1
#       x_36_6            1
#       x_37_6            1
#       x_38_6            1
#       x_39_6            1
#       x_40_6            1
#       x_41_6            1
#       x_42_6            1
#       x_43_6            1
#       x_44_6            1
#       x_45_6            1
#       x_46_6            1
#       x_47_6            1
#       x_48_6            1
#       x_49_6            1
#          y_6      9.33333
#
#       ObjVal
# ------------
#      9.33333
#
#      runtime
# ------------
#     0.012856
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.18760204315185547 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 3
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x2340641a
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 2650 rows, 2550 columns, 12600 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.105312e+02   0.000000e+00      0s
#       52    1.0333333e+01   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       50 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.9438257e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      105    1.0333333e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 105 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.033333333e+01
#
#     Variable            X
# -------------------------
#       x_0_26            1
#       x_1_26            1
#       x_2_26            1
#       x_3_26            1
#       x_4_26            1
#       x_5_26            1
#       x_6_26            1
#       x_7_26            1
#       x_8_26            1
#       x_9_26            1
#      x_10_26            1
#      x_11_26            1
#      x_12_26            1
#      x_13_26            1
#      x_14_26            1
#      x_15_26            1
#      x_16_26            1
#      x_17_26            1
#      x_18_26            1
#      x_19_26            1
#      x_20_26            1
#      x_21_26            1
#      x_22_26            1
#      x_23_26            1
#      x_24_26            1
#      x_25_26            1
#      x_26_26            1
#      x_27_26            1
#      x_28_26            1
#      x_29_26            1
#      x_30_26            1
#      x_31_26            1
#      x_32_26            1
#      x_33_26            1
#      x_34_26            1
#      x_35_26            1
#      x_36_26            1
#      x_37_26            1
#      x_38_26            1
#      x_39_26            1
#      x_40_26            1
#      x_41_26            1
#      x_42_26            1
#      x_43_26            1
#      x_44_26            1
#      x_45_26            1
#      x_46_26            1
#      x_47_26            1
#      x_48_26            1
#      x_49_26            1
#         y_26      10.3333
#
#       ObjVal
# ------------
#      10.3333
#
#      runtime
# ------------
#    0.0125349
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.16041922569274902 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 4
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x02722e11
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2649 rows, 2550 columns, 12549 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.600000e+01   0.000000e+00      0s
#       54    9.6666667e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       49 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.3559587e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      106    9.6666667e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 106 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  9.666666667e+00
#
#     Variable            X
# -------------------------
#        x_0_4            1
#        x_1_4            1
#        x_2_4            1
#        x_3_4            1
#        x_4_4            1
#        x_5_4            1
#        x_6_4            1
#        x_7_4            1
#        x_8_4            1
#        x_9_4            1
#       x_10_4            1
#       x_11_4            1
#       x_12_4            1
#       x_13_4            1
#       x_14_4            1
#       x_15_4            1
#       x_16_4            1
#       x_17_4            1
#       x_18_4            1
#       x_19_4            1
#       x_20_4            1
#       x_21_4            1
#       x_22_4            1
#       x_23_4            1
#       x_24_4            1
#       x_25_4            1
#       x_26_4            1
#       x_27_4            1
#       x_28_4            1
#       x_29_4            1
#       x_30_4            1
#       x_31_4            1
#       x_32_4            1
#       x_33_4            1
#       x_34_4            1
#       x_35_4            1
#       x_36_4            1
#       x_37_4            1
#       x_38_4            1
#       x_39_4            1
#       x_40_4            1
#       x_41_4            1
#       x_42_4            1
#       x_43_4            1
#       x_44_4            1
#       x_45_4            1
#       x_46_4            1
#       x_47_4            1
#       x_48_4            1
#       x_49_4            1
#          y_4      9.66667
#
#       ObjVal
# ------------
#      9.66667
#
#      runtime
# ------------
#     0.013093
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.16381597518920898 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 5
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0xe13a1500
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 2650 rows, 2550 columns, 12600 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.175000e+01   0.000000e+00      0s
#       56    9.6666667e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.2182525e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       59    9.6666667e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 59 iterations and 0.05 seconds (0.01 work units)
# Optimal objective  9.666666667e+00
#
#     Variable            X
# -------------------------
#       x_0_44            1
#       x_1_44            1
#       x_2_44            1
#       x_3_44            1
#       x_4_44            1
#       x_5_44            1
#       x_6_44            1
#       x_7_44            1
#       x_8_44            1
#       x_9_44            1
#      x_10_44            1
#      x_11_44            1
#      x_12_44            1
#      x_13_44            1
#      x_14_44            1
#      x_15_44            1
#      x_16_44            1
#      x_17_44            1
#      x_18_44            1
#      x_19_44            1
#      x_20_44            1
#      x_21_44            1
#      x_22_44            1
#      x_23_44            1
#      x_24_44            1
#      x_25_44            1
#      x_26_44            1
#      x_27_44            1
#      x_28_44            1
#      x_29_44            1
#      x_30_44            1
#      x_31_44            1
#      x_32_44            1
#      x_33_44            1
#      x_34_44            1
#      x_35_44            1
#      x_36_44            1
#      x_37_44            1
#      x_38_44            1
#      x_39_44            1
#      x_40_44            1
#      x_41_44            1
#      x_42_44            1
#      x_43_44            1
#      x_44_44            1
#      x_45_44            1
#      x_46_44            1
#      x_47_44            1
#      x_48_44            1
#      x_49_44            1
#         y_44      9.66667
#
#       ObjVal
# ------------
#      9.66667
#
#      runtime
# ------------
#    0.0465529
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.20513296127319336 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 6
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0xe9c79b8b
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 2649 rows, 2550 columns, 12549 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.115625e+01   0.000000e+00      0s
#       51    8.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8214596e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       54    8.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 54 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  8.000000000e+00
#
#     Variable            X
# -------------------------
#       x_0_46            1
#       x_1_46            1
#       x_2_46            1
#       x_3_46            1
#       x_4_46            1
#       x_5_46            1
#       x_6_46            1
#       x_7_46            1
#       x_8_46            1
#       x_9_46            1
#      x_10_46            1
#      x_11_46            1
#      x_12_46            1
#      x_13_46            1
#      x_14_46            1
#      x_15_46            1
#      x_16_46            1
#      x_17_46            1
#      x_18_46            1
#      x_19_46            1
#      x_20_46            1
#      x_21_46            1
#      x_22_46            1
#      x_23_46            1
#      x_24_46            1
#      x_25_46            1
#      x_26_46            1
#      x_27_46            1
#      x_28_46            1
#      x_29_46            1
#      x_30_46            1
#      x_31_46            1
#      x_32_46            1
#      x_33_46            1
#      x_34_46            1
#      x_35_46            1
#      x_36_46            1
#      x_37_46            1
#      x_38_46            1
#      x_39_46            1
#      x_40_46            1
#      x_41_46            1
#      x_42_46            1
#      x_43_46            1
#      x_44_46            1
#      x_45_46            1
#      x_46_46            1
#      x_47_46            1
#      x_48_46            1
#      x_49_46            1
#         y_46            8
#
#       ObjVal
# ------------
#            8
#
#      runtime
# ------------
#    0.0169389
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.18455886840820312 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 7
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x99d29f94
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 2648 rows, 2550 columns, 12498 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.881250e+01   0.000000e+00      0s
#       50    7.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       53    7.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 53 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  7.000000000e+00
#
#     Variable            X
# -------------------------
#        x_0_3            1
#        x_1_3            1
#        x_2_3            1
#        x_3_3            1
#        x_4_3            1
#        x_5_3            1
#        x_6_3            1
#        x_7_3            1
#        x_8_3            1
#        x_9_3            1
#       x_10_3            1
#       x_11_3            1
#       x_12_3            1
#       x_13_3            1
#       x_14_3            1
#       x_15_3            1
#       x_16_3            1
#       x_17_3            1
#       x_18_3            1
#       x_19_3            1
#       x_20_3            1
#       x_21_3            1
#       x_22_3            1
#       x_23_3            1
#       x_24_3            1
#       x_25_3            1
#       x_26_3            1
#       x_27_3            1
#       x_28_3            1
#       x_29_3            1
#       x_30_3            1
#       x_31_3            1
#       x_32_3            1
#       x_33_3            1
#       x_34_3            1
#       x_35_3            1
#       x_36_3            1
#       x_37_3            1
#       x_38_3            1
#       x_39_3            1
#       x_40_3            1
#       x_41_3            1
#       x_42_3            1
#       x_43_3            1
#       x_44_3            1
#       x_45_3            1
#       x_46_3            1
#       x_47_3            1
#       x_48_3            1
#       x_49_3            1
#          y_3            7
#
#       ObjVal
# ------------
#            7
#
#      runtime
# ------------
#     0.032999
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.19197678565979004 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 8
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0xdee3ba44
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 2650 rows, 2550 columns, 12600 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.949062e+02   0.000000e+00      0s
#       52    9.6666667e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.6837534e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       55    9.6666667e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 55 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  9.666666667e+00
#
#     Variable            X
# -------------------------
#       x_0_28            1
#       x_1_28            1
#       x_2_28            1
#       x_3_28            1
#       x_4_28            1
#       x_5_28            1
#       x_6_28            1
#       x_7_28            1
#       x_8_28            1
#       x_9_28            1
#      x_10_28            1
#      x_11_28            1
#      x_12_28            1
#      x_13_28            1
#      x_14_28            1
#      x_15_28            1
#      x_16_28            1
#      x_17_28            1
#      x_18_28            1
#      x_19_28            1
#      x_20_28            1
#      x_21_28            1
#      x_22_28            1
#      x_23_28            1
#      x_24_28            1
#      x_25_28            1
#      x_26_28            1
#      x_27_28            1
#      x_28_28            1
#      x_29_28            1
#      x_30_28            1
#      x_31_28            1
#      x_32_28            1
#      x_33_28            1
#      x_34_28            1
#      x_35_28            1
#      x_36_28            1
#      x_37_28            1
#      x_38_28            1
#      x_39_28            1
#      x_40_28            1
#      x_41_28            1
#      x_42_28            1
#      x_43_28            1
#      x_44_28            1
#      x_45_28            1
#      x_46_28            1
#      x_47_28            1
#      x_48_28            1
#      x_49_28            1
#         y_28      9.66667
#
#       ObjVal
# ------------
#      9.66667
#
#      runtime
# ------------
#    0.0109839
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.16420316696166992 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 9
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2650 rows, 2550 columns and 12600 nonzeros
# Model fingerprint: 0x8eac5057
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 2650 rows, 2550 columns, 12600 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.761562e+02   0.000000e+00      0s
#       50    8.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#       49 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1050189e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      102    8.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 102 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  8.000000000e+00
#
#     Variable            X
# -------------------------
#       x_0_39            1
#       x_1_39            1
#       x_2_39            1
#       x_3_39            1
#       x_4_39            1
#       x_5_39            1
#       x_6_39            1
#       x_7_39            1
#       x_8_39            1
#       x_9_39            1
#      x_10_39            1
#      x_11_39            1
#      x_12_39            1
#      x_13_39            1
#      x_14_39            1
#      x_15_39            1
#      x_16_39            1
#      x_17_39            1
#      x_18_39            1
#      x_19_39            1
#      x_20_39            1
#      x_21_39            1
#      x_22_39            1
#      x_23_39            1
#      x_24_39            1
#      x_25_39            1
#      x_26_39            1
#      x_27_39            1
#      x_28_39            1
#      x_29_39            1
#      x_30_39            1
#      x_31_39            1
#      x_32_39            1
#      x_33_39            1
#      x_34_39            1
#      x_35_39            1
#      x_36_39            1
#      x_37_39            1
#      x_38_39            1
#      x_39_39            1
#      x_40_39            1
#      x_41_39            1
#      x_42_39            1
#      x_43_39            1
#      x_44_39            1
#      x_45_39            1
#      x_46_39            1
#      x_47_39            1
#      x_48_39            1
#      x_49_39            1
#         y_39            8
#
#       ObjVal
# ------------
#            8
#
#      runtime
# ------------
#     0.010762
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.1645970344543457 seconds
#
# ----------------------------------------------------------------
#
#
# Total time taken to run all instances: 1.8043301105499268 seconds

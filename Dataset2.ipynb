# %%
# !pip install gurobipy
# Out:
# Requirement already satisfied: gurobipy in /Applications/anaconda3/lib/python3.8/site-packages (9.5.0)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
import gurobipy as gp
from gurobipy import GRB
from time import time

# %%
def read_data():
    data = pd.read_csv('constants.csv')
    P = data['value'][0]
    R = data['value'][1]
    n = data['value'][2]
    return (P,R,n)

# %%
def instance_data(number_of_instance):
    instance = pd.read_csv('instance_'+str(number_of_instance)+'.csv')
    m = instance.shape[0]
    p = []
    r = []
    for p_i in instance['p_i']:
        p.append(p_i)
    for r_i in instance['r_i']:
        r.append(r_i)
    return (m,p,r)

# %%
def Model( number_of_instance , m , p , r , P , R , n ):
    global model, x_vars , y_vars , run_time
    model = gp.Model("q1_instance_"+str(number_of_instance))
    x_vars = {}
    y_vars = {}
    start = time()
    for i in range(n):
        for j in range(m):
            x_vars[i,j] = 0 
    for i in range(m):
        y_vars [i] = 0
    constructVars() 
    contructConstrs()
    constructObj() 
    model.write('test.lp')
    model.optimize()
    model.printAttr('X')
    #model.printAttr('Xn')
    model.printAttr('ObjVal')
    model.printAttr('runtime')
    model.printAttr('NodeCount')
    print(f'Time taken to run: {time() - start} seconds')

# %%
def constructVars(): 
    global n , m , model, x_vars ,y_vars
    
    for i in range( m ): 
        for j in range( n ): 
            var = model.addVar( vtype = GRB.BINARY , name = "x_" + str( i ) + "_" + str( j ) ) 
            x_vars[ i , j ] = var 
    model.update()
    
    for j in range( n ):
        var_2 = model.addVar( vtype = GRB.BINARY , name = "y_" + str( j )) 
        y_vars[ j ] = var_2
    model.update()

# %%
def contructConstrs(): 
    global n , m , model , x_vars , y_vars , P , R
    
    for i in range( m ): 
        constExpr_0 = gp.LinExpr() 
        for j in range( n ): 
            constExpr_0 += 1.0 * x_vars[ i,j ] 
        model.addLConstr( lhs = constExpr_0 , sense = GRB.EQUAL , rhs = '1' ) 
    model.update()
    
    for i in range( m ):
        constExpr_1_1 = gp.LinExpr()
        constExpr_1_2 = gp.LinExpr()
        for j in range( n ):
            constExpr_1_1 = 1.0 * x_vars[i,j]
            constExpr_1_2 = 1.0 * y_vars[j]
            model.addLConstr(lhs= constExpr_1_1, sense = GRB.LESS_EQUAL , rhs = constExpr_1_2)
    model.update()
    
    for j in range( n ):
        constExpr_2 = gp.LinExpr()
        rhs_exp = gp.LinExpr()
        for i in range( m ): 
            constExpr_2 += p[j] * x_vars[ i,j ]
            rhs_exp = P * y_vars[j] 
        model.addLConstr( lhs = constExpr_2 , sense = GRB.LESS_EQUAL , rhs = rhs_exp  ) 
    model.update()
    
    for j in range( n ):
        constExpr_3 = gp.LinExpr()
        rhs_exp = gp.LinExpr()
        for i in range( m ): 
            constExpr_3 += r[j] * x_vars[ i,j ]
            rhs_exp_3 = R * y_vars[j] 
        model.addLConstr( lhs = constExpr_3 , sense = GRB.LESS_EQUAL , rhs = rhs_exp_3  ) 
    model.update()

# %%
def constructObj(): 
    global m , n , model , x_vars , y_vars
    objExpr = gp.LinExpr()
    for j in range( n ):
        objExpr += y_vars[j]
    model.setObjective( objExpr , GRB.MINIMIZE ) 
    model.update()

# %%
def processing_result(): #source: Gurobi website (https://www.gurobi.com/documentation/9.5/examples/mip2_py.html)
    if len(sys.argv) < 2:
        print('Usage: mip2.py filename')
        sys.exit(0)

    # Read and solve model

    if model.IsMIP == 0:
        print('Model is not a MIP')
        sys.exit(0)

    model.optimize()

    if model.Status == GRB.OPTIMAL:
        print('Optimal objective: %g' % model.ObjVal)
    elif model.Status == GRB.INF_OR_UNBD:
        print('Model is infeasible or unbounded')
        sys.exit(0)
    elif model.Status == GRB.INFEASIBLE:
        print('Model is infeasible')
        sys.exit(0)
    elif model.Status == GRB.UNBOUNDED:
        print('Model is unbounded')
        sys.exit(0)
    else:
        print('Optimization ended with status %d' % model.Status)
        sys.exit(0)

    # Iterate over the solutions and compute the objectives
    model.Params.OutputFlag = 0
    print('')
    for k in range(model.SolCount):
        model.Params.SolutionNumber = k
        print('Solution %d has objective %g' % (k, model.PoolObjVal))
    print('')
    model.Params.OutputFlag = 1

    fixed = model.fixed()
    fixed.Params.Presolve = 0
    fixed.optimize()

    if fixed.Status != GRB.OPTIMAL:
        print("Error: fixed model isn't optimal")
        sys.exit(1)
        
    diff = model.ObjVal - fixed.ObjVal

    if abs(diff) > 1e-6 * (1.0 + abs(model.ObjVal)):
        print('Error: objective values are different')
        sys.exit(1)

# %%
#def result(): 
    # Function for printing values of nonzero variables
    #model.optimize()
    #fixed = model.fixed()
    #fixed.Params.Presolve = 0
    #fixed.optimize()
    #for v in model.getVars():
        #if v.X != 0:
            #i = 0
            #answer = ''
            #if v.VarName[0] != 'y':
                #if len(v.VarName) == 7:
                    #if v.Varname[3] != '_':
                        #i += 1
                        #print('job',v.VarName[2:4],'is assigned to machine', v.VarName[5:len(v.VarName)])
                    #else:
                        #i += 1
                        #print('job',v.VarName[2],'is assigned to machine', v.VarName[5:len(v.VarName)])
            
            
                #if len(v.VarName) == 6:
                    #if v.VarName[4] != '_':
                        #i += 1
                        #print('job',v.VarName[2],'is assigned to machine', v.VarName[4:len(v.VarName)])
                    #else:
                        #i += 1
                        #print('job',v.VarName[2:4],'is assigned to machine', v.VarName[len(v.VarName)-1])
            
            
                #if len(v.VarName) == 5:
                    #i += 1
                    #print('job',v.VarName[2],'is assigned to machine',v.VarName[len(v.VarName)-1])

# %%
#result() # result of the optimization

# %%
runtime = time()
for i in range(10):
    number_of_instance = i
    m , p , r = instance_data( number_of_instance )
    P,R,n = read_data()
    print('\n instnce '+str(number_of_instance)+'\n--------------------')
    Model ( number_of_instance , m , p , r , P , R , n)
    print('\n----------------------------------------------------------------\n\n')
    model.printAttr('NumConstrs')
print(f'Total time taken to run all instances: {time() - runtime} seconds')
# Out:
#  instnce 0
# --------------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-19
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0x3bd50631
# Variable types: 0 continuous, 930 integer (930 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 25.0000000
# Presolve removed 570 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 420 rows, 930 columns, 2550 nonzeros
# Variable types: 0 continuous, 930 integer (930 binary)
#
# Root relaxation: objective 1.200000e+01, 385 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      12.0000000   12.00000  0.00%     -    0s
#
# Explored 1 nodes (385 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 12 25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_24            1
#       x_1_27            1
#       x_2_14            1
#        x_3_1            1
#       x_4_24            1
#       x_5_14            1
#       x_6_12            1
#       x_7_12            1
#       x_8_16            1
#        x_9_1            1
#      x_10_13            1
#      x_11_18            1
#       x_12_8            1
#      x_13_16            1
#      x_14_13            1
#      x_15_28            1
#       x_16_1            1
#       x_17_6            1
#      x_18_13            1
#      x_19_27            1
#      x_20_18            1
#       x_21_1            1
#       x_22_0            1
#       x_23_0            1
#       x_24_1            1
#       x_25_8            1
#       x_26_6            1
#      x_27_28            1
#       x_28_1            1
#      x_29_16            1
#          y_0            1
#          y_1            1
#          y_6            1
#          y_8            1
#         y_12            1
#         y_13            1
#         y_14            1
#         y_16            1
#         y_18            1
#         y_24            1
#         y_27            1
#         y_28            1
#
#       ObjVal
# ------------
#           12
#
#      runtime
# ------------
#    0.0364521
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.10609889030456543 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#          990
#
#  instnce 1
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0xf9454d96
# Variable types: 0 continuous, 930 integer (930 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 25.0000000
# Presolve removed 510 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 480 rows, 930 columns, 2670 nonzeros
# Variable types: 0 continuous, 930 integer (930 binary)
#
# Root relaxation: objective 1.200000e+01, 710 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      12.0000000   12.00000  0.00%     -    0s
#
# Explored 1 nodes (710 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 12 25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_14            1
#       x_1_22            1
#       x_2_29            1
#       x_3_10            1
#       x_4_11            1
#       x_5_28            1
#       x_6_29            1
#       x_7_11            1
#        x_8_1            1
#       x_9_13            1
#      x_10_22            1
#      x_11_14            1
#      x_12_21            1
#       x_13_8            1
#       x_14_8            1
#      x_15_28            1
#      x_16_21            1
#      x_17_13            1
#       x_18_4            1
#      x_19_10            1
#      x_20_11            1
#       x_21_5            1
#       x_22_8            1
#       x_23_5            1
#      x_24_21            1
#       x_25_1            1
#      x_26_21            1
#       x_27_4            1
#      x_28_14            1
#      x_29_13            1
#          y_1            1
#          y_4            1
#          y_5            1
#          y_8            1
#         y_10            1
#         y_11            1
#         y_13            1
#         y_14            1
#         y_21            1
#         y_22            1
#         y_28            1
#         y_29            1
#
#       ObjVal
# ------------
#           12
#
#      runtime
# ------------
#    0.0210791
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.08746027946472168 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#          990
#
#  instnce 2
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0x7dd9c86a
# Variable types: 0 continuous, 930 integer (930 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 23.0000000
# Presolve removed 510 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 480 rows, 930 columns, 2670 nonzeros
# Variable types: 0 continuous, 930 integer (930 binary)
#
# Root relaxation: objective 1.400000e+01, 256 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      14.0000000   14.00000  0.00%     -    0s
#
# Explored 1 nodes (256 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 14 23
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_28            1
#       x_1_19            1
#       x_2_24            1
#       x_3_15            1
#        x_4_2            1
#       x_5_15            1
#       x_6_21            1
#        x_7_6            1
#       x_8_20            1
#       x_9_13            1
#      x_10_16            1
#      x_11_14            1
#      x_12_21            1
#       x_13_8            1
#       x_14_4            1
#      x_15_28            1
#      x_16_18            1
#      x_17_19            1
#       x_18_4            1
#       x_19_2            1
#      x_20_18            1
#      x_21_13            1
#       x_22_8            1
#      x_23_16            1
#       x_24_6            1
#      x_25_20            1
#      x_26_24            1
#       x_27_4            1
#      x_28_14            1
#      x_29_18            1
#          y_2            1
#          y_4            1
#          y_6            1
#          y_8            1
#         y_13            1
#         y_14            1
#         y_15            1
#         y_16            1
#         y_18            1
#         y_19            1
#         y_20            1
#         y_21            1
#         y_24            1
#         y_28            1
#
#       ObjVal
# ------------
#           14
#
#      runtime
# ------------
#    0.0172541
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.08333182334899902 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#          990
#
#  instnce 3
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0x15b6df3d
# Variable types: 0 continuous, 930 integer (930 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 25.0000000
# Presolve removed 480 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 510 rows, 930 columns, 2730 nonzeros
# Variable types: 0 continuous, 930 integer (930 binary)
#
# Root relaxation: objective 1.450000e+01, 370 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   14.50000    0    5   25.00000   14.50000  42.0%     -    0s
# H    0     0                      15.0000000   14.50000  3.33%     -    0s
#      0     0   14.50000    0    5   15.00000   14.50000  3.33%     -    0s
#
# Explored 1 nodes (370 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 15 25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_26            1
#       x_1_17            1
#       x_2_29            1
#       x_3_26            1
#       x_4_17            1
#        x_5_5            1
#       x_6_29            1
#       x_7_25            1
#       x_8_20            1
#       x_9_13            1
#      x_10_22            1
#      x_11_22            1
#      x_12_21            1
#       x_13_9            1
#       x_14_8            1
#      x_15_20            1
#      x_16_18            1
#      x_17_13            1
#      x_18_12            1
#      x_19_12            1
#      x_20_18            1
#      x_21_29            1
#       x_22_8            1
#       x_23_0            1
#      x_24_21            1
#       x_25_0            1
#       x_26_5            1
#       x_27_9            1
#      x_28_14            1
#      x_29_25            1
#          y_0            1
#          y_5            1
#          y_8            1
#          y_9            1
#         y_12            1
#         y_13            1
#         y_14            1
#         y_17            1
#         y_18            1
#         y_20            1
#         y_21            1
#         y_22            1
#         y_25            1
#         y_26            1
#         y_29            1
#
#       ObjVal
# ------------
#           15
#
#      runtime
# ------------
#      0.01983
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.0841217041015625 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#          990
#
#  instnce 4
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0xadc35324
# Variable types: 0 continuous, 930 integer (930 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 20.0000000
# Presolve removed 450 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 540 rows, 930 columns, 2790 nonzeros
# Variable types: 0 continuous, 930 integer (930 binary)
#
# Root relaxation: objective 1.100000e+01, 1017 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      11.0000000   11.00000  0.00%     -    0s
#
# Explored 1 nodes (1017 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 11 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_25            1
#       x_1_20            1
#       x_2_18            1
#       x_3_25            1
#        x_4_5            1
#       x_5_19            1
#       x_6_19            1
#        x_7_2            1
#        x_8_2            1
#       x_9_22            1
#      x_10_26            1
#      x_11_18            1
#      x_12_29            1
#      x_13_27            1
#      x_14_22            1
#      x_15_29            1
#      x_16_26            1
#      x_17_27            1
#      x_18_18            1
#      x_19_25            1
#       x_20_2            1
#      x_21_20            1
#      x_22_26            1
#       x_23_9            1
#      x_24_20            1
#      x_25_20            1
#       x_26_5            1
#      x_27_19            1
#      x_28_19            1
#       x_29_9            1
#          y_2            1
#          y_5            1
#          y_9            1
#         y_18            1
#         y_19            1
#         y_20            1
#         y_22            1
#         y_25            1
#         y_26            1
#         y_27            1
#         y_29            1
#
#       ObjVal
# ------------
#           11
#
#      runtime
# ------------
#     0.022485
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.08922696113586426 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#          990
#
#  instnce 5
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0xcea4c8f4
# Variable types: 0 continuous, 930 integer (930 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 21.0000000
# Presolve removed 510 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 480 rows, 930 columns, 2670 nonzeros
# Variable types: 0 continuous, 930 integer (930 binary)
#
# Root relaxation: objective 1.250000e+01, 341 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.50000    0    5   21.00000   12.50000  40.5%     -    0s
# H    0     0                      13.0000000   12.50000  3.85%     -    0s
#      0     0   12.50000    0    5   13.00000   12.50000  3.85%     -    0s
#
# Explored 1 nodes (341 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 13 21
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#        x_0_2            1
#       x_1_19            1
#       x_2_15            1
#       x_3_19            1
#        x_4_2            1
#       x_5_21            1
#        x_6_5            1
#       x_7_25            1
#       x_8_25            1
#        x_9_1            1
#      x_10_16            1
#       x_11_7            1
#      x_12_21            1
#       x_13_8            1
#      x_14_16            1
#      x_15_20            1
#      x_16_18            1
#      x_17_19            1
#      x_18_10            1
#      x_19_10            1
#      x_20_18            1
#      x_21_19            1
#       x_22_8            1
#       x_23_1            1
#       x_24_7            1
#      x_25_20            1
#       x_26_7            1
#      x_27_19            1
#       x_28_5            1
#      x_29_25            1
#          y_1            1
#          y_2            1
#          y_5            1
#          y_7            1
#          y_8            1
#         y_10            1
#         y_15            1
#         y_16            1
#         y_18            1
#         y_19            1
#         y_20            1
#         y_21            1
#         y_25            1
#
#       ObjVal
# ------------
#           13
#
#      runtime
# ------------
#    0.0459511
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.12216687202453613 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#          990
#
#  instnce 6
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0xec449c63
# Variable types: 0 continuous, 930 integer (930 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 24.0000000
# Presolve removed 450 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 540 rows, 930 columns, 2790 nonzeros
# Variable types: 0 continuous, 930 integer (930 binary)
#
# Root relaxation: objective 1.400000e+01, 471 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      14.0000000   14.00000  0.00%     -    0s
#
# Explored 1 nodes (471 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 14 24
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#        x_0_6            1
#       x_1_24            1
#        x_2_5            1
#       x_3_24            1
#       x_4_17            1
#        x_5_8            1
#       x_6_19            1
#       x_7_21            1
#        x_8_3            1
#       x_9_14            1
#       x_10_8            1
#       x_11_6            1
#      x_12_22            1
#      x_13_27            1
#      x_14_10            1
#      x_15_14            1
#      x_16_10            1
#      x_17_27            1
#      x_18_12            1
#      x_19_15            1
#      x_20_17            1
#      x_21_22            1
#      x_22_15            1
#       x_23_3            1
#      x_24_12            1
#      x_25_10            1
#       x_26_3            1
#      x_27_19            1
#       x_28_5            1
#      x_29_21            1
#          y_3            1
#          y_5            1
#          y_6            1
#          y_8            1
#         y_10            1
#         y_12            1
#         y_14            1
#         y_15            1
#         y_17            1
#         y_19            1
#         y_21            1
#         y_22            1
#         y_24            1
#         y_27            1
#
#       ObjVal
# ------------
#           14
#
#      runtime
# ------------
#    0.0367098
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.12651705741882324 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#          990
#
#  instnce 7
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0x4c2daf0a
# Variable types: 0 continuous, 930 integer (930 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 22.0000000
# Presolve removed 420 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 570 rows, 930 columns, 2850 nonzeros
# Variable types: 0 continuous, 930 integer (930 binary)
#
# Root relaxation: objective 1.000000e+01, 908 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      10.0000000   10.00000  0.00%     -    0s
#
# Explored 1 nodes (908 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 10 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_17            1
#       x_1_17            1
#       x_2_19            1
#        x_3_9            1
#       x_4_29            1
#       x_5_25            1
#       x_6_13            1
#       x_7_13            1
#       x_8_15            1
#        x_9_9            1
#       x_10_4            1
#      x_11_22            1
#      x_12_25            1
#      x_13_22            1
#       x_14_9            1
#       x_15_4            1
#       x_16_0            1
#      x_17_29            1
#       x_18_4            1
#      x_19_15            1
#       x_20_4            1
#      x_21_29            1
#      x_22_19            1
#      x_23_15            1
#       x_24_9            1
#      x_25_17            1
#      x_26_19            1
#      x_27_15            1
#      x_28_25            1
#       x_29_0            1
#          y_0            1
#          y_4            1
#          y_9            1
#         y_13            1
#         y_15            1
#         y_17            1
#         y_19            1
#         y_22            1
#         y_25            1
#         y_29            1
#
#       ObjVal
# ------------
#           10
#
#      runtime
# ------------
#     0.025651
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.09400415420532227 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#          990
#
#  instnce 8
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0x04241b02
# Variable types: 0 continuous, 930 integer (930 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 25.0000000
# Presolve removed 510 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 480 rows, 930 columns, 2670 nonzeros
# Variable types: 0 continuous, 930 integer (930 binary)
#
# Root relaxation: objective 1.300000e+01, 732 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      13.0000000   13.00000  0.00%     -    0s
#
# Explored 1 nodes (732 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 13 25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_10            1
#       x_1_11            1
#       x_2_15            1
#       x_3_16            1
#       x_4_17            1
#        x_5_1            1
#       x_6_17            1
#       x_7_11            1
#       x_8_18            1
#       x_9_13            1
#      x_10_27            1
#      x_11_20            1
#       x_12_0            1
#       x_13_8            1
#      x_14_16            1
#      x_15_20            1
#      x_16_18            1
#      x_17_13            1
#      x_18_10            1
#      x_19_10            1
#      x_20_11            1
#       x_21_1            1
#       x_22_8            1
#       x_23_0            1
#       x_24_6            1
#      x_25_11            1
#      x_26_27            1
#      x_27_15            1
#      x_28_27            1
#       x_29_6            1
#          y_0            1
#          y_1            1
#          y_6            1
#          y_8            1
#         y_10            1
#         y_11            1
#         y_13            1
#         y_15            1
#         y_16            1
#         y_17            1
#         y_18            1
#         y_20            1
#         y_27            1
#
#       ObjVal
# ------------
#           13
#
#      runtime
# ------------
#    0.0235531
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.09223580360412598 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#          990
#
#  instnce 9
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0x7e40bbb5
# Variable types: 0 continuous, 930 integer (930 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 23.0000000
# Presolve removed 450 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 540 rows, 930 columns, 2790 nonzeros
# Variable types: 0 continuous, 930 integer (930 binary)
#
# Root relaxation: objective 1.000000e+01, 955 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      10.0000000   10.00000  0.00%     -    0s
#
# Explored 1 nodes (955 simplex iterations) in 0.03 seconds (0.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 10 23
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x_0_25            1
#       x_1_24            1
#       x_2_13            1
#       x_3_24            1
#       x_4_13            1
#        x_5_3            1
#        x_6_9            1
#        x_7_1            1
#        x_8_3            1
#       x_9_21            1
#      x_10_21            1
#      x_11_13            1
#      x_12_12            1
#      x_13_25            1
#       x_14_1            1
#      x_15_29            1
#       x_16_4            1
#      x_17_25            1
#      x_18_12            1
#      x_19_24            1
#      x_20_21            1
#      x_21_12            1
#      x_22_29            1
#       x_23_3            1
#      x_24_12            1
#      x_25_29            1
#      x_26_29            1
#       x_27_4            1
#      x_28_13            1
#       x_29_9            1
#          y_1            1
#          y_3            1
#          y_4            1
#          y_9            1
#         y_12            1
#         y_13            1
#         y_21            1
#         y_24            1
#         y_25            1
#         y_29            1
#
#       ObjVal
# ------------
#           10
#
#      runtime
# ------------
#    0.0309122
#
#    NodeCount
# ------------
#            1
# Time taken to run: 0.09911394119262695 seconds
#
# ----------------------------------------------------------------
#
#
#
#   NumConstrs
# ------------
#          990
# Total time taken to run all instances: 1.0547568798065186 seconds

# %% [markdown]
# ## Relaxation:

# %%
def constructVars_relax(): 
    global n , m , model_2, x_vars ,y_vars
    
    for i in range( m ): 
        for j in range( n ): 
            var = model_2.addVar( vtype = GRB.CONTINUOUS , name = "x_" + str( i ) + "_" + str( j ) ) 
            x_vars[ i , j ] = var 
    model_2.update()
    
    for j in range( n ):
        var_2 = model_2.addVar( vtype = GRB.CONTINUOUS , name = "y_" + str( j )) 
        y_vars[ j ] = var_2
    model_2.update()

# %%
def contructConstrs(): 
    global n , m , model_2 , x_vars , y_vars , P , R
    
    for i in range( m ): 
        constExpr_0 = gp.LinExpr() 
        for j in range( n ): 
            constExpr_0 += 1.0 * x_vars[ i,j ] 
        model_2.addLConstr( lhs = constExpr_0 , sense = GRB.EQUAL , rhs = '1' ) 
    model_2.update()
    
    for i in range( m ):
        constExpr_1_1 = gp.LinExpr()
        constExpr_1_2 = gp.LinExpr()
        for j in range( n ):
            constExpr_1_1 = 1.0 * x_vars[i,j]
            constExpr_1_2 = 1.0 * y_vars[j]
            model_2.addLConstr(lhs= constExpr_1_1, sense = GRB.LESS_EQUAL , rhs = constExpr_1_2)
    model_2.update()
    
    for j in range( n ):
        constExpr_2 = gp.LinExpr()
        rhs_exp = gp.LinExpr()
        for i in range( m ): 
            constExpr_2 += p[j] * x_vars[ i,j ]
            rhs_exp = P * y_vars[j] 
        model_2.addLConstr( lhs = constExpr_2 , sense = GRB.LESS_EQUAL , rhs = rhs_exp  ) 
    model_2.update()
    
    for j in range( n ):
        constExpr_3 = gp.LinExpr()
        rhs_exp = gp.LinExpr()
        for i in range( m ): 
            constExpr_3 += r[j] * x_vars[ i,j ]
            rhs_exp_3 = R * y_vars[j] 
        model_2.addLConstr( lhs = constExpr_3 , sense = GRB.LESS_EQUAL , rhs = rhs_exp_3  ) 
    model_2.update()

# %%
def constructObj(): 
    global m , n , model_2 , x_vars , y_vars
    objExpr = gp.LinExpr()
    for j in range( n ):
        objExpr += y_vars[j]
    model_2.setObjective( objExpr , GRB.MINIMIZE ) 
    model_2.update()

# %%
def Model( number_of_instance , m , p , r , P , R , n ):
    global model_2, x_vars , y_vars , run_time
    model_2 = gp.Model("q1_instance_"+str(number_of_instance))
    x_vars = {}
    y_vars = {}
    start = time()
    for i in range(n):
        for j in range(m):
            x_vars[i,j] = 0 
    for i in range(m):
        y_vars [i] = 0
    constructVars_relax() 
    contructConstrs()
    constructObj() 
    model_2.write('test.lp')
    model_2.optimize()
    model_2.printAttr('X')
    #model.printAttr('Xn')
    model_2.printAttr('ObjVal')
    model_2.printAttr('runtime')
    model_2.printAttr('NodeCount')
    print(f'Time taken to run: {time() - start} seconds')

# %%
runtime = time()
for i in range(10):
    number_of_instance = i
    m , p , r = instance_data( number_of_instance )
    P,R,n = read_data()
    print('\n instnce '+str(number_of_instance)+'\n--------------------')
    Model ( number_of_instance , m , p , r , P , R , n)
    print('\n----------------------------------------------------------------\n\n')

print(f'Total time taken to run all instances: {time() - runtime} seconds')
# Out:
#  instnce 0
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0x6ff074f4
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 990 rows, 930 columns, 4560 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.088125e+02   0.000000e+00      0s
#       30    4.6000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.9388939e-18      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       34    4.6000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.600000000e+00
#
#     Variable            X
# -------------------------
#        x_0_1            1
#        x_1_1            1
#        x_2_1            1
#        x_3_1            1
#        x_4_1            1
#        x_5_1            1
#        x_6_1            1
#        x_7_1            1
#        x_8_1            1
#        x_9_1            1
#       x_10_1            1
#       x_11_1            1
#       x_12_1            1
#       x_13_1            1
#       x_14_1            1
#       x_15_1            1
#       x_16_1            1
#       x_17_1            1
#       x_18_1            1
#       x_19_1            1
#       x_20_1            1
#       x_21_1            1
#       x_22_1            1
#       x_23_1            1
#       x_24_1            1
#       x_25_1            1
#       x_26_1            1
#       x_27_1            1
#       x_28_1            1
#       x_29_1            1
#          y_1          4.6
#
#       ObjVal
# ------------
#          4.6
#
#      runtime
# ------------
#    0.0113151
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.0976099967956543 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 1
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0xa28329fa
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 989 rows, 930 columns, 4529 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.818750e+01   0.000000e+00      0s
#       36    6.4000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.0740662e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       39    6.4000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.400000000e+00
#
#     Variable            X
# -------------------------
#       x_0_21            1
#       x_1_21            1
#       x_2_21            1
#       x_3_21            1
#       x_4_21            1
#       x_5_21            1
#       x_6_21            1
#       x_7_21            1
#       x_8_21            1
#       x_9_21            1
#      x_10_21            1
#      x_11_21            1
#      x_12_21            1
#      x_13_21            1
#      x_14_21            1
#      x_15_21            1
#      x_16_21            1
#      x_17_21            1
#      x_18_21            1
#      x_19_21            1
#      x_20_21            1
#      x_21_21            1
#      x_22_21            1
#      x_23_21            1
#      x_24_21            1
#      x_25_21            1
#      x_26_21            1
#      x_27_21            1
#      x_28_21            1
#      x_29_21            1
#         y_21          6.4
#
#       ObjVal
# ------------
#          6.4
#
#      runtime
# ------------
#    0.0143261
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.08997702598571777 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 2
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0xa1a137c4
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 990 rows, 930 columns, 4560 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.334375e+01   0.000000e+00      0s
#       39    9.8000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.8980598e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       42    9.8000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 42 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  9.800000000e+00
#
#     Variable            X
# -------------------------
#       x_0_18            1
#       x_1_18            1
#       x_2_18            1
#       x_3_18            1
#       x_4_18            1
#       x_5_18            1
#       x_6_18            1
#       x_7_18            1
#       x_8_18            1
#       x_9_18            1
#      x_10_18            1
#      x_11_18            1
#      x_12_18            1
#      x_13_18            1
#      x_14_18            1
#      x_15_18            1
#      x_16_18            1
#      x_17_18            1
#      x_18_18            1
#      x_19_18            1
#      x_20_18            1
#      x_21_18            1
#      x_22_18            1
#      x_23_18            1
#      x_24_18            1
#      x_25_18            1
#      x_26_18            1
#      x_27_18            1
#      x_28_18            1
#      x_29_18            1
#         y_18          9.8
#
#       ObjVal
# ------------
#          9.8
#
#      runtime
# ------------
#     0.021122
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.09371685981750488 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 3
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0xd3711aa3
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 989 rows, 930 columns, 4529 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.475000e+01   0.000000e+00      0s
#       36    8.2000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.8521577e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       39    8.2000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.200000000e+00
#
#     Variable            X
# -------------------------
#       x_0_29            1
#       x_1_29            1
#       x_2_29            1
#       x_3_29            1
#       x_4_29            1
#       x_5_29            1
#       x_6_29            1
#       x_7_29            1
#       x_8_29            1
#       x_9_29            1
#      x_10_29            1
#      x_11_29            1
#      x_12_29            1
#      x_13_29            1
#      x_14_29            1
#      x_15_29            1
#      x_16_29            1
#      x_17_29            1
#      x_18_29            1
#      x_19_29            1
#      x_20_29            1
#      x_21_29            1
#      x_22_29            1
#      x_23_29            1
#      x_24_29            1
#      x_25_29            1
#      x_26_29            1
#      x_27_29            1
#      x_28_29            1
#      x_29_29            1
#         y_29          8.2
#
#       ObjVal
# ------------
#          8.2
#
#      runtime
# ------------
#   0.00942993
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.06869983673095703 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 4
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0xa016c8ae
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 989 rows, 930 columns, 4529 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.975000e+01   0.000000e+00      0s
#       35    7.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.8980598e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       38    7.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.000000000e+00
#
#     Variable            X
# -------------------------
#       x_0_19            1
#       x_1_19            1
#       x_2_19            1
#       x_3_19            1
#       x_4_19            1
#       x_5_19            1
#       x_6_19            1
#       x_7_19            1
#       x_8_19            1
#       x_9_19            1
#      x_10_19            1
#      x_11_19            1
#      x_12_19            1
#      x_13_19            1
#      x_14_19            1
#      x_15_19            1
#      x_16_19            1
#      x_17_19            1
#      x_18_19            1
#      x_19_19            1
#      x_20_19            1
#      x_21_19            1
#      x_22_19            1
#      x_23_19            1
#      x_24_19            1
#      x_25_19            1
#      x_26_19            1
#      x_27_19            1
#      x_28_19            1
#      x_29_19            1
#         y_19            7
#
#       ObjVal
# ------------
#            7
#
#      runtime
# ------------
#   0.00910592
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.0689389705657959 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 5
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0xf43681de
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 990 rows, 930 columns, 4560 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.027188e+02   0.000000e+00      0s
#       33    5.6000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.1850204e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       36    5.6000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 36 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.600000000e+00
#
#     Variable            X
# -------------------------
#       x_0_19            1
#       x_1_19            1
#       x_2_19            1
#       x_3_19            1
#       x_4_19            1
#       x_5_19            1
#       x_6_19            1
#       x_7_19            1
#       x_8_19            1
#       x_9_19            1
#      x_10_19            1
#      x_11_19            1
#      x_12_19            1
#      x_13_19            1
#      x_14_19            1
#      x_15_19            1
#      x_16_19            1
#      x_17_19            1
#      x_18_19            1
#      x_19_19            1
#      x_20_19            1
#      x_21_19            1
#      x_22_19            1
#      x_23_19            1
#      x_24_19            1
#      x_25_19            1
#      x_26_19            1
#      x_27_19            1
#      x_28_19            1
#      x_29_19            1
#         y_19          5.6
#
#       ObjVal
# ------------
#          5.6
#
#      runtime
# ------------
#   0.00892401
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.06946206092834473 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 6
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0x5cee2960
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 990 rows, 930 columns, 4560 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.069375e+02   0.000000e+00      0s
#       36    9.6000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 9.4542429e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       39    9.6000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.600000000e+00
#
#     Variable            X
# -------------------------
#       x_0_10            1
#       x_1_10            1
#       x_2_10            1
#       x_3_10            1
#       x_4_10            1
#       x_5_10            1
#       x_6_10            1
#       x_7_10            1
#       x_8_10            1
#       x_9_10            1
#      x_10_10            1
#      x_11_10            1
#      x_12_10            1
#      x_13_10            1
#      x_14_10            1
#      x_15_10            1
#      x_16_10            1
#      x_17_10            1
#      x_18_10            1
#      x_19_10            1
#      x_20_10            1
#      x_21_10            1
#      x_22_10            1
#      x_23_10            1
#      x_24_10            1
#      x_25_10            1
#      x_26_10            1
#      x_27_10            1
#      x_28_10            1
#      x_29_10            1
#         y_10          9.6
#
#       ObjVal
# ------------
#          9.6
#
#      runtime
# ------------
#   0.00795698
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.0682058334350586 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 7
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0xbff47a02
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 990 rows, 930 columns, 4560 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.275625e+02   0.000000e+00      0s
#       35    6.4000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.5485811e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       38    6.4000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.400000000e+00
#
#     Variable            X
# -------------------------
#        x_0_4            1
#        x_1_4            1
#        x_2_4            1
#        x_3_4            1
#        x_4_4            1
#        x_5_4            1
#        x_6_4            1
#        x_7_4            1
#        x_8_4            1
#        x_9_4            1
#       x_10_4            1
#       x_11_4            1
#       x_12_4            1
#       x_13_4            1
#       x_14_4            1
#       x_15_4            1
#       x_16_4            1
#       x_17_4            1
#       x_18_4            1
#       x_19_4            1
#       x_20_4            1
#       x_21_4            1
#       x_22_4            1
#       x_23_4            1
#       x_24_4            1
#       x_25_4            1
#       x_26_4            1
#       x_27_4            1
#       x_28_4            1
#       x_29_4            1
#          y_4          6.4
#
#       ObjVal
# ------------
#          6.4
#
#      runtime
# ------------
#   0.00694609
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.0670769214630127 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 8
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0x85882ea6
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 989 rows, 930 columns, 4529 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.256250e+01   0.000000e+00      0s
#       36    6.4000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.7679556e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       39    6.4000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.400000000e+00
#
#     Variable            X
# -------------------------
#       x_0_11            1
#       x_1_11            1
#       x_2_11            1
#       x_3_11            1
#       x_4_11            1
#       x_5_11            1
#       x_6_11            1
#       x_7_11            1
#       x_8_11            1
#       x_9_11            1
#      x_10_11            1
#      x_11_11            1
#      x_12_11            1
#      x_13_11            1
#      x_14_11            1
#      x_15_11            1
#      x_16_11            1
#      x_17_11            1
#      x_18_11            1
#      x_19_11            1
#      x_20_11            1
#      x_21_11            1
#      x_22_11            1
#      x_23_11            1
#      x_24_11            1
#      x_25_11            1
#      x_26_11            1
#      x_27_11            1
#      x_28_11            1
#      x_29_11            1
#         y_11          6.4
#
#       ObjVal
# ------------
#          6.4
#
#      runtime
# ------------
#   0.00899005
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.07175683975219727 seconds
#
# ----------------------------------------------------------------
#
#
#
#  instnce 9
# --------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 990 rows, 930 columns and 4560 nonzeros
# Model fingerprint: 0x1843c856
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 990 rows, 930 columns, 4560 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.135000e+02   0.000000e+00      0s
#       37    7.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.2500725e-17      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       40    7.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 40 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  7.000000000e+00
#
#     Variable            X
# -------------------------
#       x_0_29            1
#       x_1_29            1
#       x_2_29            1
#       x_3_29            1
#       x_4_29            1
#       x_5_29            1
#       x_6_29            1
#       x_7_29            1
#       x_8_29            1
#       x_9_29            1
#      x_10_29            1
#      x_11_29            1
#      x_12_29            1
#      x_13_29            1
#      x_14_29            1
#      x_15_29            1
#      x_16_29            1
#      x_17_29            1
#      x_18_29            1
#      x_19_29            1
#      x_20_29            1
#      x_21_29            1
#      x_22_29            1
#      x_23_29            1
#      x_24_29            1
#      x_25_29            1
#      x_26_29            1
#      x_27_29            1
#      x_28_29            1
#      x_29_29            1
#         y_29            7
#
#       ObjVal
# ------------
#            7
#
#      runtime
# ------------
#     0.044992
#
#    NodeCount
# ------------
#            0
# Time taken to run: 0.10678887367248535 seconds
#
# ----------------------------------------------------------------
#
#
# Total time taken to run all instances: 0.8417432308197021 seconds
